# %% [markdown]
# # 🤗 x 🦾: Training ACT with LeRobot Notebook
#
# Welcome to the **LeRobot ACT training notebook**! This notebook provides a ready-to-run setup for training imitation learning policies using the [🤗 LeRobot](https://github.com/huggingface/lerobot) library.
#
# In this example, we train an `ACT` policy using a dataset hosted on the [Hugging Face Hub](https://huggingface.co/), and optionally track training metrics with [Weights & Biases (wandb)](https://wandb.ai/).
#
# ## ⚙️ Requirements
# - A Hugging Face dataset repo ID containing your training data (`--dataset.repo_id=YOUR_USERNAME/YOUR_DATASET`)
# - Optional: A [wandb](https://wandb.ai/) account if you want to enable training visualization
# - Recommended: GPU runtime (e.g., NVIDIA A100) for faster training
#
# ## ⏱️ Expected Training Time
# Training with the `ACT` policy for 100,000 steps typically takes **about 1.5 hours on an NVIDIA A100** GPU. On less powerful GPUs or CPUs, training may take significantly longer.
#
# ## Example Output
# Model checkpoints, logs, and training plots will be saved to the specified `--output_dir`. If `wandb` is enabled, progress will also be visualized in your wandb project dashboard.

# %% [markdown]
# ## Install conda
# This cell uses `condacolab` to bootstrap a full Conda environment inside Google Colab.

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ✨🍰✨ Everything looks OK!

# %% [markdown]
# ## Install LeRobot
# This cell clones the `lerobot` repository from Hugging Face, installs FFmpeg (version 7.1.1), and installs the package in editable mode.

# %%
# !git clone https://github.com/huggingface/lerobot.git
# !conda install ffmpeg=7.1.1 -c conda-forge
# !cd lerobot && pip install -e .
# Out:
# Cloning into 'lerobot'...
# remote: Enumerating objects: 32745, done.
# remote: Counting objects: 100% (82/82), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 32745 (delta 58), reused 38 (delta 36), pack-reused 32663 (from 3)
# Receiving objects: 100% (32745/32745), 163.75 MiB | 15.50 MiB/s, done.
# Resolving deltas: 100% (20935/20935), done.
# Filtering content: 100% (45/45), 69.04 MiB | 22.11 MiB/s, done.
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - ffmpeg=7.1.1
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     alsa-lib-1.2.14            |       hb9d3cd8_0         553 KB  conda-forge
#     aom-3.9.1                  |       hac33072_0         2.6 MB  conda-forge
#     attr-2.5.1                 |       h166bdaf_1          69 KB  conda-forge
#     ca-certificates-2025.8.3   |       hbd8a1cb_0         151 KB  conda-forge
#     cairo-1.18.4               |       h3394656_0         955 KB  conda-forge
#     certifi-2025.8.3           |     pyhd8ed1ab_0         155 KB  conda-forge
#     conda-24.11.3              |  py311h38be061_0         1.1 MB  conda-forge
#     dav1d-1.2.1                |       hd590300_0         742 KB  conda-forge
#     dbus-1.16.2                |       h3c4dab8_0         428 KB  conda-forge
#     ffmpeg-7.1.1               | gpl_hd51cf9b_709        10.0 MB  conda-forge
#     font-ttf-dejavu-sans-mono-2.37|       hab24e00_0         388 KB  conda-forge
#     font-ttf-inconsolata-3.000 |       h77eed37_0          94 KB  conda-forge
#     font-ttf-source-code-pro-2.038|       h77eed37_0         684 KB  conda-forge
#     font-ttf-ubuntu-0.83       |       h77eed37_3         1.5 MB  conda-forge
#     fontconfig-2.15.0          |       h7e30c49_1         259 KB  conda-forge
#     fonts-conda-ecosystem-1    |                0           4 KB  conda-forge
#     fonts-conda-forge-1        |                0           4 KB  conda-forge
#     freetype-2.13.3            |       ha770c72_1         168 KB  conda-forge
#     fribidi-1.0.10             |       h36c2ea0_0         112 KB  conda-forge
#     gdk-pixbuf-2.42.12         |       h2b0a6b4_3         566 KB  conda-forge
#     gettext-0.25.1             |       h3f43e3d_1         529 KB  conda-forge
#     gettext-tools-0.25.1       |       h3f43e3d_1         3.5 MB  conda-forge
#     gmp-6.3.0                  |       hac33072_2         449 KB  conda-forge
#     graphite2-1.3.14           |       hecca717_2          97 KB  conda-forge
#     harfbuzz-11.4.4            |       h15599e2_0         2.3 MB  conda-forge
#     icu-75.1                   |       he02047a_0        11.6 MB  conda-forge
#     lame-3.100                 |    h166bdaf_1003         496 KB  conda-forge
#     lerc-4.0.0                 |       h0aef613_1         258 KB  conda-forge
#     level-zero-1.24.2          |       hb700be7_0         592 KB  conda-forge
#     libabseil-20250512.1       | cxx17_hba17884_0         1.2 MB  conda-forge
#     libasprintf-0.25.1         |       h3f43e3d_1          52 KB  conda-forge
#     libasprintf-devel-0.25.1   |       h3f43e3d_1          34 KB  conda-forge
#     libass-0.17.4              |       h96ad9f0_0         149 KB  conda-forge
#     libcap-2.71                |       h39aace5_0         100 KB  conda-forge
#     libdeflate-1.23            |       h86f0d12_0          71 KB  conda-forge
#     libdrm-2.4.125             |       hb9d3cd8_0         240 KB  conda-forge
#     libegl-1.7.0               |       ha4b6fd6_2          44 KB  conda-forge
#     libexpat-2.7.1             |       hecca717_0          73 KB  conda-forge
#     libffi-3.4.6               |       h2dba641_1          56 KB  conda-forge
#     libflac-1.4.3              |       h59595ed_0         385 KB  conda-forge
#     libfreetype-2.13.3         |       ha770c72_1           8 KB  conda-forge
#     libfreetype6-2.13.3        |       h48d6fc4_1         371 KB  conda-forge
#     libgcrypt-lib-1.11.1       |       hb9d3cd8_0         577 KB  conda-forge
#     libgettextpo-0.25.1        |       h3f43e3d_1         184 KB  conda-forge
#     libgettextpo-devel-0.25.1  |       h3f43e3d_1          37 KB  conda-forge
#     libgl-1.7.0                |       ha4b6fd6_2         132 KB  conda-forge
#     libglib-2.84.3             |       hf39c6af_0         3.8 MB  conda-forge
#     libglvnd-1.7.0             |       ha4b6fd6_2         129 KB  conda-forge
#     libglx-1.7.0               |       ha4b6fd6_2          74 KB  conda-forge
#     libgpg-error-1.55          |       h3f2d84a_0         305 KB  conda-forge
#     libhwloc-2.12.1            |default_h3d81e11_1000         2.3 MB  conda-forge
#     libiconv-1.18              |       h3b78370_2         772 KB  conda-forge
#     libjpeg-turbo-3.1.0        |       hb9d3cd8_0         614 KB  conda-forge
#     liblzma-5.8.1              |       hb9d3cd8_2         110 KB  conda-forge
#     libogg-1.3.5               |       hd0c01bc_1         213 KB  conda-forge
#     libopenvino-2025.2.0       |       hb617929_1         6.0 MB  conda-forge
#     libopenvino-auto-batch-plugin-2025.2.0|       hed573e4_1         112 KB  conda-forge
#     libopenvino-auto-plugin-2025.2.0|       hed573e4_1         245 KB  conda-forge
#     libopenvino-hetero-plugin-2025.2.0|       hd41364c_1         190 KB  conda-forge
#     libopenvino-intel-cpu-plugin-2025.2.0|       hb617929_1        11.8 MB  conda-forge
#     libopenvino-intel-gpu-plugin-2025.2.0|       hb617929_1        10.3 MB  conda-forge
#     libopenvino-intel-npu-plugin-2025.2.0|       hb617929_1         1.2 MB  conda-forge
#     libopenvino-ir-frontend-2025.2.0|       hd41364c_1         200 KB  conda-forge
#     libopenvino-onnx-frontend-2025.2.0|       h1862bb8_1         1.6 MB  conda-forge
#     libopenvino-paddle-frontend-2025.2.0|       h1862bb8_1         727 KB  conda-forge
#     libopenvino-pytorch-frontend-2025.2.0|       hecca717_1         1.2 MB  conda-forge
#     libopenvino-tensorflow-frontend-2025.2.0|       h0767aad_1         1.3 MB  conda-forge
#     libopenvino-tensorflow-lite-frontend-2025.2.0|       hecca717_1         485 KB  conda-forge
#     libopus-1.5.2              |       hd0c01bc_0         305 KB  conda-forge
#     libpciaccess-0.18          |       hb9d3cd8_0          28 KB  conda-forge
#     libpng-1.6.50              |       h421ea60_1         310 KB  conda-forge
#     libprotobuf-6.31.1         |       h9ef548d_1         3.8 MB  conda-forge
#     librsvg-2.58.4             |       he92a37e_3         6.2 MB  conda-forge
#     libsndfile-1.2.2           |       hc60ed4a_1         346 KB  conda-forge
#     libsystemd0-257.3          |       h3dc2cb9_0         476 KB  conda-forge
#     libtiff-4.7.0              |       hd9ff511_3         418 KB  conda-forge
#     libudev1-257.4             |       h9a4d06a_0         140 KB  conda-forge
#     libunwind-1.6.2            |       h9c3ff4c_0          74 KB  conda-forge
#     liburing-2.9               |       h84d6215_0         118 KB  conda-forge
#     libusb-1.0.29              |       h73b1eb8_0          87 KB  conda-forge
#     libva-2.22.0               |       h4f16b4b_2         212 KB  conda-forge
#     libvorbis-1.3.7            |       h54a6638_2         279 KB  conda-forge
#     libvpx-1.14.1              |       hac33072_0         999 KB  conda-forge
#     libwebp-base-1.6.0         |       hd42ef1d_0         419 KB  conda-forge
#     libxcb-1.17.0              |       h8a09558_0         387 KB  conda-forge
#     libxkbcommon-1.11.0        |       he8b52b9_0         773 KB  conda-forge
#     libxml2-2.13.8             |       h04c0eec_1         682 KB  conda-forge
#     mpg123-1.32.9              |       hc50e24c_0         480 KB  conda-forge
#     ocl-icd-2.3.3              |       hb9d3cd8_0         104 KB  conda-forge
#     opencl-headers-2025.06.13  |       h5888daf_0          54 KB  conda-forge
#     openh264-2.6.0             |       hc22cd8d_0         714 KB  conda-forge
#     openssl-3.5.2              |       h26f9b46_0         3.0 MB  conda-forge
#     pango-1.56.4               |       hadf4263_0         445 KB  conda-forge
#     pcre2-10.45                |       hc749103_0         1.1 MB  conda-forge
#     pixman-0.46.4              |       h54a6638_1         440 KB  conda-forge
#     pthread-stubs-0.4          |    hb9d3cd8_1002           8 KB  conda-forge
#     pugixml-1.15               |       h3f63f65_0         116 KB  conda-forge
#     pulseaudio-client-17.0     |       hb77b528_0         740 KB  conda-forge
#     sdl2-2.32.54               |       h3f2d84a_0         573 KB  conda-forge
#     sdl3-3.2.14                |       he3e324a_0         1.8 MB  conda-forge
#     snappy-1.2.2               |       h03e3b7b_0          45 KB  conda-forge
#     svt-av1-3.1.2              |       hecca717_0         2.6 MB  conda-forge
#     tbb-2022.2.0               |       hb60516a_1         179 KB  conda-forge
#     wayland-1.24.0             |       h3e06ad9_0         323 KB  conda-forge
#     wayland-protocols-1.45     |       hd8ed1ab_0         135 KB  conda-forge
#     x264-1!164.3095            |       h166bdaf_2         877 KB  conda-forge
#     x265-3.5                   |       h924138e_3         3.2 MB  conda-forge
#     xkeyboard-config-2.45      |       hb9d3cd8_0         383 KB  conda-forge
#     xorg-libice-1.1.2          |       hb9d3cd8_0          57 KB  conda-forge
#     xorg-libsm-1.2.6           |       he73a12e_0          27 KB  conda-forge
#     xorg-libx11-1.8.12         |       h4f16b4b_0         816 KB  conda-forge
#     xorg-libxau-1.0.12         |       hb9d3cd8_0          14 KB  conda-forge
#     xorg-libxcursor-1.2.3      |       hb9d3cd8_0          32 KB  conda-forge
#     xorg-libxdmcp-1.1.5        |       hb9d3cd8_0          19 KB  conda-forge
#     xorg-libxext-1.3.6         |       hb9d3cd8_0          49 KB  conda-forge
#     xorg-libxfixes-6.0.1       |       hb9d3cd8_0          19 KB  conda-forge
#     xorg-libxrender-0.9.12     |       hb9d3cd8_0          32 KB  conda-forge
#     xorg-libxscrnsaver-1.2.4   |       hb9d3cd8_0          14 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       121.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   alsa-lib           conda-forge/linux-64::alsa-lib-1.2.14-hb9d3cd8_0
#   aom                conda-forge/linux-64::aom-3.9.1-hac33072_0
#   attr               conda-forge/linux-64::attr-2.5.1-h166bdaf_1
#   cairo              conda-forge/linux-64::cairo-1.18.4-h3394656_0
#   dav1d              conda-forge/linux-64::dav1d-1.2.1-hd590300_0
#   dbus               conda-forge/linux-64::dbus-1.16.2-h3c4dab8_0
#   ffmpeg             conda-forge/linux-64::ffmpeg-7.1.1-gpl_hd51cf9b_709
#   font-ttf-dejavu-s~ conda-forge/noarch::font-ttf-dejavu-sans-mono-2.37-hab24e00_0
#   font-ttf-inconsol~ conda-forge/noarch::font-ttf-inconsolata-3.000-h77eed37_0
#   font-ttf-source-c~ conda-forge/noarch::font-ttf-source-code-pro-2.038-h77eed37_0
#   font-ttf-ubuntu    conda-forge/noarch::font-ttf-ubuntu-0.83-h77eed37_3
#   fontconfig         conda-forge/linux-64::fontconfig-2.15.0-h7e30c49_1
#   fonts-conda-ecosy~ conda-forge/noarch::fonts-conda-ecosystem-1-0
#   fonts-conda-forge  conda-forge/noarch::fonts-conda-forge-1-0
#   freetype           conda-forge/linux-64::freetype-2.13.3-ha770c72_1
#   fribidi            conda-forge/linux-64::fribidi-1.0.10-h36c2ea0_0
#   gdk-pixbuf         conda-forge/linux-64::gdk-pixbuf-2.42.12-h2b0a6b4_3
#   gettext            conda-forge/linux-64::gettext-0.25.1-h3f43e3d_1
#   gettext-tools      conda-forge/linux-64::gettext-tools-0.25.1-h3f43e3d_1
#   gmp                conda-forge/linux-64::gmp-6.3.0-hac33072_2
#   graphite2          conda-forge/linux-64::graphite2-1.3.14-hecca717_2
#   harfbuzz           conda-forge/linux-64::harfbuzz-11.4.4-h15599e2_0
#   icu                conda-forge/linux-64::icu-75.1-he02047a_0
#   lame               conda-forge/linux-64::lame-3.100-h166bdaf_1003
#   lerc               conda-forge/linux-64::lerc-4.0.0-h0aef613_1
#   level-zero         conda-forge/linux-64::level-zero-1.24.2-hb700be7_0
#   libabseil          conda-forge/linux-64::libabseil-20250512.1-cxx17_hba17884_0
#   libasprintf        conda-forge/linux-64::libasprintf-0.25.1-h3f43e3d_1
#   libasprintf-devel  conda-forge/linux-64::libasprintf-devel-0.25.1-h3f43e3d_1
#   libass             conda-forge/linux-64::libass-0.17.4-h96ad9f0_0
#   libcap             conda-forge/linux-64::libcap-2.71-h39aace5_0
#   libdeflate         conda-forge/linux-64::libdeflate-1.23-h86f0d12_0
#   libdrm             conda-forge/linux-64::libdrm-2.4.125-hb9d3cd8_0
#   libegl             conda-forge/linux-64::libegl-1.7.0-ha4b6fd6_2
#   libflac            conda-forge/linux-64::libflac-1.4.3-h59595ed_0
#   libfreetype        conda-forge/linux-64::libfreetype-2.13.3-ha770c72_1
#   libfreetype6       conda-forge/linux-64::libfreetype6-2.13.3-h48d6fc4_1
#   libgcrypt-lib      conda-forge/linux-64::libgcrypt-lib-1.11.1-hb9d3cd8_0
#   libgettextpo       conda-forge/linux-64::libgettextpo-0.25.1-h3f43e3d_1
#   libgettextpo-devel conda-forge/linux-64::libgettextpo-devel-0.25.1-h3f43e3d_1
#   libgl              conda-forge/linux-64::libgl-1.7.0-ha4b6fd6_2
#   libglib            conda-forge/linux-64::libglib-2.84.3-hf39c6af_0
#   libglvnd           conda-forge/linux-64::libglvnd-1.7.0-ha4b6fd6_2
#   libglx             conda-forge/linux-64::libglx-1.7.0-ha4b6fd6_2
#   libgpg-error       conda-forge/linux-64::libgpg-error-1.55-h3f2d84a_0
#   libhwloc           conda-forge/linux-64::libhwloc-2.12.1-default_h3d81e11_1000
#   libjpeg-turbo      conda-forge/linux-64::libjpeg-turbo-3.1.0-hb9d3cd8_0
#   libogg             conda-forge/linux-64::libogg-1.3.5-hd0c01bc_1
#   libopenvino        conda-forge/linux-64::libopenvino-2025.2.0-hb617929_1
#   libopenvino-auto-~ conda-forge/linux-64::libopenvino-auto-batch-plugin-2025.2.0-hed573e4_1
#   libopenvino-auto-~ conda-forge/linux-64::libopenvino-auto-plugin-2025.2.0-hed573e4_1
#   libopenvino-heter~ conda-forge/linux-64::libopenvino-hetero-plugin-2025.2.0-hd41364c_1
#   libopenvino-intel~ conda-forge/linux-64::libopenvino-intel-cpu-plugin-2025.2.0-hb617929_1
#   libopenvino-intel~ conda-forge/linux-64::libopenvino-intel-gpu-plugin-2025.2.0-hb617929_1
#   libopenvino-intel~ conda-forge/linux-64::libopenvino-intel-npu-plugin-2025.2.0-hb617929_1
#   libopenvino-ir-fr~ conda-forge/linux-64::libopenvino-ir-frontend-2025.2.0-hd41364c_1
#   libopenvino-onnx-~ conda-forge/linux-64::libopenvino-onnx-frontend-2025.2.0-h1862bb8_1
#   libopenvino-paddl~ conda-forge/linux-64::libopenvino-paddle-frontend-2025.2.0-h1862bb8_1
#   libopenvino-pytor~ conda-forge/linux-64::libopenvino-pytorch-frontend-2025.2.0-hecca717_1
#   libopenvino-tenso~ conda-forge/linux-64::libopenvino-tensorflow-frontend-2025.2.0-h0767aad_1
#   libopenvino-tenso~ conda-forge/linux-64::libopenvino-tensorflow-lite-frontend-2025.2.0-hecca717_1
#   libopus            conda-forge/linux-64::libopus-1.5.2-hd0c01bc_0
#   libpciaccess       conda-forge/linux-64::libpciaccess-0.18-hb9d3cd8_0
#   libpng             conda-forge/linux-64::libpng-1.6.50-h421ea60_1
#   libprotobuf        conda-forge/linux-64::libprotobuf-6.31.1-h9ef548d_1
#   librsvg            conda-forge/linux-64::librsvg-2.58.4-he92a37e_3
#   libsndfile         conda-forge/linux-64::libsndfile-1.2.2-hc60ed4a_1
#   libsystemd0        conda-forge/linux-64::libsystemd0-257.3-h3dc2cb9_0
#   libtiff            conda-forge/linux-64::libtiff-4.7.0-hd9ff511_3
#   libudev1           conda-forge/linux-64::libudev1-257.4-h9a4d06a_0
#   libunwind          conda-forge/linux-64::libunwind-1.6.2-h9c3ff4c_0
#   liburing           conda-forge/linux-64::liburing-2.9-h84d6215_0
#   libusb             conda-forge/linux-64::libusb-1.0.29-h73b1eb8_0
#   libva              conda-forge/linux-64::libva-2.22.0-h4f16b4b_2
#   libvorbis          conda-forge/linux-64::libvorbis-1.3.7-h54a6638_2
#   libvpx             conda-forge/linux-64::libvpx-1.14.1-hac33072_0
#   libwebp-base       conda-forge/linux-64::libwebp-base-1.6.0-hd42ef1d_0
#   libxcb             conda-forge/linux-64::libxcb-1.17.0-h8a09558_0
#   libxkbcommon       conda-forge/linux-64::libxkbcommon-1.11.0-he8b52b9_0
#   mpg123             conda-forge/linux-64::mpg123-1.32.9-hc50e24c_0
#   ocl-icd            conda-forge/linux-64::ocl-icd-2.3.3-hb9d3cd8_0
#   opencl-headers     conda-forge/linux-64::opencl-headers-2025.06.13-h5888daf_0
#   openh264           conda-forge/linux-64::openh264-2.6.0-hc22cd8d_0
#   pango              conda-forge/linux-64::pango-1.56.4-hadf4263_0
#   pcre2              conda-forge/linux-64::pcre2-10.45-hc749103_0
#   pixman             conda-forge/linux-64::pixman-0.46.4-h54a6638_1
#   pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-hb9d3cd8_1002
#   pugixml            conda-forge/linux-64::pugixml-1.15-h3f63f65_0
#   pulseaudio-client  conda-forge/linux-64::pulseaudio-client-17.0-hb77b528_0
#   sdl2               conda-forge/linux-64::sdl2-2.32.54-h3f2d84a_0
#   sdl3               conda-forge/linux-64::sdl3-3.2.14-he3e324a_0
#   snappy             conda-forge/linux-64::snappy-1.2.2-h03e3b7b_0
#   svt-av1            conda-forge/linux-64::svt-av1-3.1.2-hecca717_0
#   tbb                conda-forge/linux-64::tbb-2022.2.0-hb60516a_1
#   wayland            conda-forge/linux-64::wayland-1.24.0-h3e06ad9_0
#   wayland-protocols  conda-forge/noarch::wayland-protocols-1.45-hd8ed1ab_0
#   x264               conda-forge/linux-64::x264-1!164.3095-h166bdaf_2
#   x265               conda-forge/linux-64::x265-3.5-h924138e_3
#   xkeyboard-config   conda-forge/linux-64::xkeyboard-config-2.45-hb9d3cd8_0
#   xorg-libice        conda-forge/linux-64::xorg-libice-1.1.2-hb9d3cd8_0
#   xorg-libsm         conda-forge/linux-64::xorg-libsm-1.2.6-he73a12e_0
#   xorg-libx11        conda-forge/linux-64::xorg-libx11-1.8.12-h4f16b4b_0
#   xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.12-hb9d3cd8_0
#   xorg-libxcursor    conda-forge/linux-64::xorg-libxcursor-1.2.3-hb9d3cd8_0
#   xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.5-hb9d3cd8_0
#   xorg-libxext       conda-forge/linux-64::xorg-libxext-1.3.6-hb9d3cd8_0
#   xorg-libxfixes     conda-forge/linux-64::xorg-libxfixes-6.0.1-hb9d3cd8_0
#   xorg-libxrender    conda-forge/linux-64::xorg-libxrender-0.9.12-hb9d3cd8_0
#   xorg-libxscrnsaver conda-forge/linux-64::xorg-libxscrnsaver-1.2.4-hb9d3cd8_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge/linux-64::ca-certificates~ --> conda-forge/noarch::ca-certificates-2025.8.3-hbd8a1cb_0
#   certifi                           2024.12.14-pyhd8ed1ab_0 --> 2025.8.3-pyhd8ed1ab_0
#   conda                             24.11.2-py311h38be061_1 --> 24.11.3-py311h38be061_0
#   libexpat                                 2.6.4-h5888daf_0 --> 2.7.1-hecca717_0
#   libffi                                   3.4.2-h7f98852_5 --> 3.4.6-h2dba641_1
#   libiconv                                  1.17-hd590300_2 --> 1.18-h3b78370_2
#   liblzma                                  5.6.3-hb9d3cd8_1 --> 5.8.1-hb9d3cd8_2
#   libxml2                                 2.13.5-h0d44e9d_1 --> 2.13.8-h04c0eec_1
#   openssl                                  3.4.0-h7b32b05_1 --> 3.5.2-h26f9b46_0
#
#
#
# Downloading and Extracting Packages:
# libopenvino-intel-cp | 11.8 MB   | :   0% 0/1 [00:00<?, ?it/s]
# icu-75.1             | 11.6 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
# libopenvino-intel-gp | 10.3 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
# ffmpeg-7.1.1         | 10.0 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# librsvg-2.58.4       | 6.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# libopenvino-2025.2.0 | 6.0 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# libprotobuf-6.31.1   | 3.8 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# libglib-2.84.3       | 3.8 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# gettext-tools-0.25.1 | 3.5 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# x265-3.5             | 3.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# openssl-3.5.2        | 3.0 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# svt-av1-3.1.2        | 2.6 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# aom-3.9.1            | 2.6 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# libhwloc-2.12.1      | 2.3 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-11.4.4      | 2.3 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sdl3-3.2.14          | 1.8 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-onnx-fro | 1.6 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-tensorfl | 1.3 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-intel-cp | 11.8 MB   | :  16% 0.1588432160063496/1 [00:00<00:00,  1.59it/s]
# icu-75.1             | 11.6 MB   | :   0% 0.00135078949540213/1 [00:00<01:15, 75.22s/it]
#
#
# ffmpeg-7.1.1         | 10.0 MB   | :   4% 0.04377185720866628/1 [00:00<00:02,  2.29s/it]
#
#
#
# librsvg-2.58.4       | 6.2 MB    | :  13% 0.13270145366860184/1 [00:00<00:00,  1.31it/s]
#
# libopenvino-intel-cp | 11.8 MB   | :  44% 0.4434373113510593/1 [00:00<00:00,  2.24it/s]
#
#
# ffmpeg-7.1.1         | 10.0 MB   | :  44% 0.4392818527012581/1 [00:00<00:00,  2.43it/s]
#
#
#
# librsvg-2.58.4       | 6.2 MB    | :  68% 0.6835376764439302/1 [00:00<00:00,  3.64it/s]
# icu-75.1             | 11.6 MB   | :  33% 0.3309434263735218/1 [00:00<00:00,  1.78it/s]
#
# libopenvino-intel-cp | 11.8 MB   | :  79% 0.7902449996315892/1 [00:00<00:00,  2.79it/s]
#
#
# ffmpeg-7.1.1         | 10.0 MB   | :  85% 0.8488613737252069/1 [00:00<00:00,  3.16it/s]
# icu-75.1             | 11.6 MB   | :  72% 0.7226723800401395/1 [00:00<00:00,  2.70it/s]
#
# libopenvino-intel-gp | 10.3 MB   | :  80% 0.8013639709009679/1 [00:00<00:00,  3.00it/s]
#
#
#
# librsvg-2.58.4       | 6.2 MB    | : 100% 1.0/1 [00:00<00:00,  3.64it/s]
#
#
#
#
# libopenvino-2025.2.0 | 6.0 MB    | :   0% 0.0026236350380182075/1 [00:00<02:34, 154.93s/it]
#
#
#
#
# libopenvino-2025.2.0 | 6.0 MB    | :  69% 0.6926396500368068/1 [00:00<00:00,  1.79it/s]
#
#
# ffmpeg-7.1.1         | 10.0 MB   | : 100% 1.0/1 [00:00<00:00,  3.16it/s]
# icu-75.1             | 11.6 MB   | : 100% 1.0/1 [00:00<00:00,  1.74it/s]
# icu-75.1             | 11.6 MB   | : 100% 1.0/1 [00:00<00:00,  1.74it/s]
#
# libopenvino-intel-gp | 10.3 MB   | : 100% 1.0/1 [00:00<00:00,  3.00it/s]
#
#
#
#
#
# libprotobuf-6.31.1   | 3.8 MB    | :   0% 0.004080450423548463/1 [00:00<02:26, 146.60s/it]
#
#
#
#
#
#
# libopenvino-intel-cp | 11.8 MB   | : 100% 1.0/1 [00:00<00:00,  2.79it/s]
#
#
#
#
#
#
#
# gettext-tools-0.25.1 | 3.5 MB    | :   0% 0.00449603098485416/1 [00:00<02:19, 140.38s/it]
#
#
#
#
#
#
#
#
# x265-3.5             | 3.2 MB    | :   0% 0.004880274801411181/1 [00:00<02:17, 138.65s/it]
#
#
#
#
#
# libprotobuf-6.31.1   | 3.8 MB    | :  79% 0.7875269317448533/1 [00:00<00:00,  1.51it/s]
#
#
#
#
#
#
# libglib-2.84.3       | 3.8 MB    | :  82% 0.81880734465972/1 [00:00<00:00,  1.56it/s]
#
#
#
#
# libopenvino-2025.2.0 | 6.0 MB    | : 100% 1.0/1 [00:00<00:00,  1.79it/s]
#
#
#
#
#
#
#
# gettext-tools-0.25.1 | 3.5 MB    | :  91% 0.9081982589405404/1 [00:00<00:00,  1.67it/s]
#
#
#
#
#
#
#
#
#
# openssl-3.5.2        | 3.0 MB    | :   1% 0.005236433740607962/1 [00:00<02:23, 144.73s/it]
#
#
#
#
#
# libprotobuf-6.31.1   | 3.8 MB    | : 100% 1.0/1 [00:00<00:00,  1.51it/s]
#
#
#
#
#
#
# libglib-2.84.3       | 3.8 MB    | : 100% 1.0/1 [00:00<00:00,  1.56it/s]
#
#
#
#
#
#
#
# gettext-tools-0.25.1 | 3.5 MB    | : 100% 1.0/1 [00:00<00:00,  1.67it/s]
#
#
#
#
#
#
#
#
# x265-3.5             | 3.2 MB    | : 100% 1.0/1 [00:00<00:00,  1.60it/s]
#
#
#
#
#
#
#
#
# x265-3.5             | 3.2 MB    | : 100% 1.0/1 [00:00<00:00,  1.60it/s]
#
#
#
#
#
#
#
#
#
# openssl-3.5.2        | 3.0 MB    | : 100% 1.0/1 [00:00<00:00, 144.73s/it]
#
#
#
#
#
#
#
#
#
#
#
# aom-3.9.1            | 2.6 MB    | :   1% 0.006053807351178468/1 [00:00<02:23, 143.89s/it]
#
#
#
#
#
#
#
#
#
#
# svt-av1-3.1.2        | 2.6 MB    | :   1% 0.005976944403910696/1 [00:00<02:26, 147.80s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# libhwloc-2.12.1      | 2.3 MB    | :   1% 0.006686195275752503/1 [00:00<02:11, 132.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-11.4.4      | 2.3 MB    | :   1% 0.006785315821166508/1 [00:00<02:09, 130.84s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sdl3-3.2.14          | 1.8 MB    | :   1% 0.008446710556841557/1 [00:00<01:46, 107.58s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-11.4.4      | 2.3 MB    | : 100% 1.0/1 [00:01<00:00,  1.35it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-11.4.4      | 2.3 MB    | : 100% 1.0/1 [00:01<00:00,  1.35it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sdl3-3.2.14          | 1.8 MB    | : 100% 1.0/1 [00:01<00:00, 107.58s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# libhwloc-2.12.1      | 2.3 MB    | : 100% 1.0/1 [00:01<00:00,  1.32it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# libhwloc-2.12.1      | 2.3 MB    | : 100% 1.0/1 [00:01<00:00,  1.32it/s]
#
#
#
#
#
#
#
#
#
#
#
# aom-3.9.1            | 2.6 MB    | : 100% 1.0/1 [00:01<00:00,  1.32it/s]
#
#
#
#
#
#
#
#
#
#
#
# aom-3.9.1            | 2.6 MB    | : 100% 1.0/1 [00:01<00:00,  1.32it/s]
#
#
#
#
#
#
#
#
#
#
# svt-av1-3.1.2        | 2.6 MB    | : 100% 1.0/1 [00:01<00:00,  1.31it/s]
#
#
#
#
#
#
#
#
#
#
# svt-av1-3.1.2        | 2.6 MB    | : 100% 1.0/1 [00:01<00:00,  1.31it/s]
#
#
#
# librsvg-2.58.4       | 6.2 MB    | : 100% 1.0/1 [00:01<00:00,  3.64it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | :   1% 0.010110434778315882/1 [00:01<01:43, 104.17s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-onnx-fro | 1.6 MB    | :   1% 0.00950070832002032/1 [00:01<01:49, 110.95s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-tensorfl | 1.3 MB    | :   1% 0.012364732438329161/1 [00:01<01:25, 86.89s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | : 100% 1.0/1 [00:01<00:00, 104.17s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-onnx-fro | 1.6 MB    | : 100% 1.0/1 [00:01<00:00, 110.95s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-tensorfl | 1.3 MB    | : 100% 1.0/1 [00:01<00:00, 86.89s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
# ffmpeg-7.1.1         | 10.0 MB   | : 100% 1.0/1 [00:01<00:00,  3.16it/s]
# icu-75.1             | 11.6 MB   | : 100% 1.0/1 [00:02<00:00,  1.74it/s]
#
# libopenvino-intel-gp | 10.3 MB   | : 100% 1.0/1 [00:02<00:00,  3.00it/s]
#
#
#
#
# libopenvino-intel-cp | 11.8 MB   | : 100% 1.0/1 [00:02<00:00,  2.79it/s]
#
#
#
#
#
# libprotobuf-6.31.1   | 3.8 MB    | : 100% 1.0/1 [00:02<00:00,  1.51it/s]
#
#
#
#
#
#
# libglib-2.84.3       | 3.8 MB    | : 100% 1.0/1 [00:02<00:00,  1.56it/s]
#
#
#
#
#
#
#
# gettext-tools-0.25.1 | 3.5 MB    | : 100% 1.0/1 [00:02<00:00,  1.67it/s]
#
#
#
#
#
#
#
#
#
# openssl-3.5.2        | 3.0 MB    | : 100% 1.0/1 [00:03<00:00,  2.94s/it]
#
#
#
#
#
#
#
#
#
# openssl-3.5.2        | 3.0 MB    | : 100% 1.0/1 [00:03<00:00,  2.94s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sdl3-3.2.14          | 1.8 MB    | : 100% 1.0/1 [00:03<00:00,  3.02s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sdl3-3.2.14          | 1.8 MB    | : 100% 1.0/1 [00:03<00:00,  3.02s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-11.4.4      | 2.3 MB    | : 100% 1.0/1 [00:03<00:00,  1.35it/s]
#
#
#
#
#
#
#
#
#
#
#
# aom-3.9.1            | 2.6 MB    | : 100% 1.0/1 [00:03<00:00,  1.32it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# libhwloc-2.12.1      | 2.3 MB    | : 100% 1.0/1 [00:03<00:00,  1.32it/s]
#
#
#
#
#
#
#
#
# x265-3.5             | 3.2 MB    | : 100% 1.0/1 [00:03<00:00,  1.60it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | : 100% 1.0/1 [00:03<00:00,  3.47s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | : 100% 1.0/1 [00:03<00:00,  3.47s/it]
#
#
#
#
#
#
#
#
#
#
# svt-av1-3.1.2        | 2.6 MB    | : 100% 1.0/1 [00:03<00:00,  1.31it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-tensorfl | 1.3 MB    | : 100% 1.0/1 [00:03<00:00,  3.59s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-tensorfl | 1.3 MB    | : 100% 1.0/1 [00:03<00:00,  3.59s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-onnx-fro | 1.6 MB    | : 100% 1.0/1 [00:03<00:00,  3.61s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-onnx-fro | 1.6 MB    | : 100% 1.0/1 [00:03<00:00,  3.61s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# |
# |
# done
# Obtaining file:///content/lerobot
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Collecting datasets<=3.6.0,>=2.19.0 (from lerobot==0.3.4)
#   Downloading datasets-3.6.0-py3-none-any.whl.metadata (19 kB)
# Collecting diffusers>=0.27.2 (from lerobot==0.3.4)
#   Downloading diffusers-0.35.1-py3-none-any.whl.metadata (20 kB)
# Collecting huggingface-hub>=0.34.2 (from huggingface-hub[cli,hf-transfer]>=0.34.2->lerobot==0.3.4)
#   Downloading huggingface_hub-0.34.4-py3-none-any.whl.metadata (14 kB)
# Collecting cmake>=3.29.0.1 (from lerobot==0.3.4)
#   Downloading cmake-4.1.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.5 kB)
# Collecting einops>=0.8.0 (from lerobot==0.3.4)
#   Downloading einops-0.8.1-py3-none-any.whl.metadata (13 kB)
# Collecting opencv-python-headless>=4.9.0 (from lerobot==0.3.4)
#   Downloading opencv_python_headless-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (19 kB)
# Collecting av>=14.2.0 (from lerobot==0.3.4)
#   Downloading av-15.0.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (4.6 kB)
# Collecting jsonlines>=4.0.0 (from lerobot==0.3.4)
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: packaging>=24.2 in /usr/local/lib/python3.11/site-packages (from lerobot==0.3.4) (24.2)
# Collecting pynput>=1.7.7 (from lerobot==0.3.4)
#   Downloading pynput-1.8.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting pyserial>=3.5 (from lerobot==0.3.4)
#   Downloading pyserial-3.5-py2.py3-none-any.whl.metadata (1.6 kB)
# Collecting wandb>=0.20.0 (from lerobot==0.3.4)
#   Downloading wandb-0.21.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting torch<2.8.0,>=2.2.1 (from lerobot==0.3.4)
#   Downloading torch-2.7.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Collecting torchcodec<0.6.0,>=0.2.1 (from lerobot==0.3.4)
#   Downloading torchcodec-0.5-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (10 kB)
# Collecting torchvision<0.23.0,>=0.21.0 (from lerobot==0.3.4)
#   Downloading torchvision-0.22.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Collecting draccus==0.10.0 (from lerobot==0.3.4)
#   Downloading draccus-0.10.0-py3-none-any.whl.metadata (24 kB)
# Collecting gymnasium<1.0.0,>=0.29.1 (from lerobot==0.3.4)
#   Downloading gymnasium-0.29.1-py3-none-any.whl.metadata (10 kB)
# Collecting rerun-sdk<0.23.0,>=0.21.0 (from lerobot==0.3.4)
#   Downloading rerun_sdk-0.22.1-cp38-abi3-manylinux_2_31_x86_64.whl.metadata (4.4 kB)
# Collecting deepdiff<9.0.0,>=7.0.1 (from lerobot==0.3.4)
#   Downloading deepdiff-8.6.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting flask<4.0.0,>=3.0.3 (from lerobot==0.3.4)
#   Downloading flask-3.1.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting imageio<3.0.0,>=2.34.0 (from imageio[ffmpeg]<3.0.0,>=2.34.0->lerobot==0.3.4)
#   Downloading imageio-2.37.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting termcolor<4.0.0,>=2.4.0 (from lerobot==0.3.4)
#   Downloading termcolor-3.1.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting mergedeep~=1.3 (from draccus==0.10.0->lerobot==0.3.4)
#   Downloading mergedeep-1.3.4-py3-none-any.whl.metadata (4.3 kB)
# Collecting pyyaml~=6.0 (from draccus==0.10.0->lerobot==0.3.4)
#   Downloading PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting pyyaml-include~=1.4 (from draccus==0.10.0->lerobot==0.3.4)
#   Downloading pyyaml_include-1.4.1-py3-none-any.whl.metadata (1.3 kB)
# Collecting toml~=0.10 (from draccus==0.10.0->lerobot==0.3.4)
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Collecting typing-inspect~=0.9.0 (from draccus==0.10.0->lerobot==0.3.4)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting filelock (from datasets<=3.6.0,>=2.19.0->lerobot==0.3.4)
#   Downloading filelock-3.19.1-py3-none-any.whl.metadata (2.1 kB)
# Collecting numpy>=1.17 (from datasets<=3.6.0,>=2.19.0->lerobot==0.3.4)
#   Downloading numpy-2.3.2-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Collecting pyarrow>=15.0.0 (from datasets<=3.6.0,>=2.19.0->lerobot==0.3.4)
#   Downloading pyarrow-21.0.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets<=3.6.0,>=2.19.0->lerobot==0.3.4)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting pandas (from datasets<=3.6.0,>=2.19.0->lerobot==0.3.4)
#   Downloading pandas-2.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (91 kB)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/site-packages (from datasets<=3.6.0,>=2.19.0->lerobot==0.3.4) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/site-packages (from datasets<=3.6.0,>=2.19.0->lerobot==0.3.4) (4.67.1)
# Collecting xxhash (from datasets<=3.6.0,>=2.19.0->lerobot==0.3.4)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets<=3.6.0,>=2.19.0->lerobot==0.3.4)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2025.3.0,>=2023.1.0 (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=3.6.0,>=2.19.0->lerobot==0.3.4)
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Collecting orderly-set<6,>=5.4.1 (from deepdiff<9.0.0,>=7.0.1->lerobot==0.3.4)
#   Downloading orderly_set-5.5.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting importlib_metadata (from diffusers>=0.27.2->lerobot==0.3.4)
#   Downloading importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting regex!=2019.12.17 (from diffusers>=0.27.2->lerobot==0.3.4)
#   Downloading regex-2025.7.34-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# Collecting safetensors>=0.3.1 (from diffusers>=0.27.2->lerobot==0.3.4)
#   Downloading safetensors-0.6.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Collecting Pillow (from diffusers>=0.27.2->lerobot==0.3.4)
#   Downloading pillow-11.3.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (9.0 kB)
# Collecting blinker>=1.9.0 (from flask<4.0.0,>=3.0.3->lerobot==0.3.4)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting click>=8.1.3 (from flask<4.0.0,>=3.0.3->lerobot==0.3.4)
#   Downloading click-8.2.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting itsdangerous>=2.2.0 (from flask<4.0.0,>=3.0.3->lerobot==0.3.4)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting jinja2>=3.1.2 (from flask<4.0.0,>=3.0.3->lerobot==0.3.4)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting markupsafe>=2.1.1 (from flask<4.0.0,>=3.0.3->lerobot==0.3.4)
#   Downloading MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting werkzeug>=3.1.0 (from flask<4.0.0,>=3.0.3->lerobot==0.3.4)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting cloudpickle>=1.2.0 (from gymnasium<1.0.0,>=0.29.1->lerobot==0.3.4)
#   Downloading cloudpickle-3.1.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting typing-extensions>=4.3.0 (from gymnasium<1.0.0,>=0.29.1->lerobot==0.3.4)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting farama-notifications>=0.0.1 (from gymnasium<1.0.0,>=0.29.1->lerobot==0.3.4)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Collecting hf-xet<2.0.0,>=1.1.3 (from huggingface-hub>=0.34.2->huggingface-hub[cli,hf-transfer]>=0.34.2->lerobot==0.3.4)
#   Downloading hf_xet-1.1.9-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.7 kB)
# Collecting InquirerPy==0.3.4 (from huggingface-hub[cli,hf-transfer]>=0.34.2->lerobot==0.3.4)
#   Downloading InquirerPy-0.3.4-py3-none-any.whl.metadata (8.1 kB)
# Collecting hf-transfer>=0.1.4 (from huggingface-hub[cli,hf-transfer]>=0.34.2->lerobot==0.3.4)
#   Downloading hf_transfer-0.1.9-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting pfzy<0.4.0,>=0.3.1 (from InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]>=0.34.2->lerobot==0.3.4)
#   Downloading pfzy-0.3.4-py3-none-any.whl.metadata (4.9 kB)
# Collecting prompt-toolkit<4.0.0,>=3.0.1 (from InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]>=0.34.2->lerobot==0.3.4)
#   Downloading prompt_toolkit-3.0.52-py3-none-any.whl.metadata (6.4 kB)
# Collecting imageio-ffmpeg (from imageio[ffmpeg]<3.0.0,>=2.34.0->lerobot==0.3.4)
#   Downloading imageio_ffmpeg-0.6.0-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting psutil (from imageio[ffmpeg]<3.0.0,>=2.34.0->lerobot==0.3.4)
#   Downloading psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting attrs>=19.2.0 (from jsonlines>=4.0.0->lerobot==0.3.4)
#   Downloading attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting numpy>=1.17 (from datasets<=3.6.0,>=2.19.0->lerobot==0.3.4)
#   Downloading numpy-2.2.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting six (from pynput>=1.7.7->lerobot==0.3.4)
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting evdev>=1.3 (from pynput>=1.7.7->lerobot==0.3.4)
#   Downloading evdev-1.9.2.tar.gz (33 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting python-xlib>=0.17 (from pynput>=1.7.7->lerobot==0.3.4)
#   Downloading python_xlib-0.33-py2.py3-none-any.whl.metadata (6.2 kB)
# Collecting sympy>=1.13.3 (from torch<2.8.0,>=2.2.1->lerobot==0.3.4)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch<2.8.0,>=2.2.1->lerobot==0.3.4)
#   Downloading networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.6.77 (from torch<2.8.0,>=2.2.1->lerobot==0.3.4)
#   Downloading nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.6.77 (from torch<2.8.0,>=2.2.1->lerobot==0.3.4)
#   Downloading nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.6.80 (from torch<2.8.0,>=2.2.1->lerobot==0.3.4)
#   Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.5.1.17 (from torch<2.8.0,>=2.2.1->lerobot==0.3.4)
#   Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.6.4.1 (from torch<2.8.0,>=2.2.1->lerobot==0.3.4)
#   Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.3.0.4 (from torch<2.8.0,>=2.2.1->lerobot==0.3.4)
#   Downloading nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.7.77 (from torch<2.8.0,>=2.2.1->lerobot==0.3.4)
#   Downloading nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.7.1.2 (from torch<2.8.0,>=2.2.1->lerobot==0.3.4)
#   Downloading nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.5.4.2 (from torch<2.8.0,>=2.2.1->lerobot==0.3.4)
#   Downloading nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.3 (from torch<2.8.0,>=2.2.1->lerobot==0.3.4)
#   Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.26.2 (from torch<2.8.0,>=2.2.1->lerobot==0.3.4)
#   Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvtx-cu12==12.6.77 (from torch<2.8.0,>=2.2.1->lerobot==0.3.4)
#   Downloading nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nvjitlink-cu12==12.6.85 (from torch<2.8.0,>=2.2.1->lerobot==0.3.4)
#   Downloading nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufile-cu12==1.11.1.6 (from torch<2.8.0,>=2.2.1->lerobot==0.3.4)
#   Downloading nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.3.1 (from torch<2.8.0,>=2.2.1->lerobot==0.3.4)
#   Downloading triton-3.3.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: setuptools>=40.8.0 in /usr/local/lib/python3.11/site-packages (from triton==3.3.1->torch<2.8.0,>=2.2.1->lerobot==0.3.4) (65.6.3)
# Collecting gitpython!=3.1.29,>=1.0.0 (from wandb>=0.20.0->lerobot==0.3.4)
#   Downloading gitpython-3.1.45-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/site-packages (from wandb>=0.20.0->lerobot==0.3.4) (4.3.6)
# Collecting protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 (from wandb>=0.20.0->lerobot==0.3.4)
#   Downloading protobuf-6.32.0-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Collecting pydantic<3 (from wandb>=0.20.0->lerobot==0.3.4)
#   Downloading pydantic-2.11.7-py3-none-any.whl.metadata (67 kB)
# Collecting sentry-sdk>=2.0.0 (from wandb>=0.20.0->lerobot==0.3.4)
#   Downloading sentry_sdk-2.35.1-py2.py3-none-any.whl.metadata (10 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=3.6.0,>=2.19.0->lerobot==0.3.4)
#   Downloading aiohttp-3.12.15-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.29,>=1.0.0->wandb>=0.20.0->lerobot==0.3.4)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3->wandb>=0.20.0->lerobot==0.3.4)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic<3->wandb>=0.20.0->lerobot==0.3.4)
#   Downloading pydantic_core-2.33.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic<3->wandb>=0.20.0->lerobot==0.3.4)
#   Downloading typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/site-packages (from requests>=2.32.2->datasets<=3.6.0,>=2.19.0->lerobot==0.3.4) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/site-packages (from requests>=2.32.2->datasets<=3.6.0,>=2.19.0->lerobot==0.3.4) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/site-packages (from requests>=2.32.2->datasets<=3.6.0,>=2.19.0->lerobot==0.3.4) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/site-packages (from requests>=2.32.2->datasets<=3.6.0,>=2.19.0->lerobot==0.3.4) (2025.8.3)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch<2.8.0,>=2.2.1->lerobot==0.3.4)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect~=0.9.0->draccus==0.10.0->lerobot==0.3.4)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting zipp>=3.20 (from importlib_metadata->diffusers>=0.27.2->lerobot==0.3.4)
#   Downloading zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting python-dateutil>=2.8.2 (from pandas->datasets<=3.6.0,>=2.19.0->lerobot==0.3.4)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas->datasets<=3.6.0,>=2.19.0->lerobot==0.3.4)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->datasets<=3.6.0,>=2.19.0->lerobot==0.3.4)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=3.6.0,>=2.19.0->lerobot==0.3.4)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=3.6.0,>=2.19.0->lerobot==0.3.4)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=3.6.0,>=2.19.0->lerobot==0.3.4)
#   Downloading frozenlist-1.7.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=3.6.0,>=2.19.0->lerobot==0.3.4)
#   Downloading multidict-6.6.4-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=3.6.0,>=2.19.0->lerobot==0.3.4)
#   Downloading propcache-0.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=3.6.0,>=2.19.0->lerobot==0.3.4)
#   Downloading yarl-1.20.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (73 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb>=0.20.0->lerobot==0.3.4)
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Collecting wcwidth (from prompt-toolkit<4.0.0,>=3.0.1->InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]>=0.34.2->lerobot==0.3.4)
#   Downloading wcwidth-0.2.13-py2.py3-none-any.whl.metadata (14 kB)
# Downloading draccus-0.10.0-py3-none-any.whl (71 kB)
# Downloading av-15.0.0-cp311-cp311-manylinux_2_28_x86_64.whl (39.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.7/39.7 MB 34.6 MB/s eta 0:00:00
# Downloading cmake-4.1.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (29.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.7/29.7 MB 61.5 MB/s eta 0:00:00
# Downloading datasets-3.6.0-py3-none-any.whl (491 kB)
# Downloading deepdiff-8.6.0-py3-none-any.whl (91 kB)
# Downloading diffusers-0.35.1-py3-none-any.whl (4.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 34.7 MB/s eta 0:00:00
# Downloading einops-0.8.1-py3-none-any.whl (64 kB)
# Downloading flask-3.1.2-py3-none-any.whl (103 kB)
# Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 44.5 MB/s eta 0:00:00
# Downloading huggingface_hub-0.34.4-py3-none-any.whl (561 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.5/561.5 kB 22.6 MB/s eta 0:00:00
# Downloading InquirerPy-0.3.4-py3-none-any.whl (67 kB)
# Downloading imageio-2.37.0-py3-none-any.whl (315 kB)
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Downloading opencv_python_headless-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (54.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 MB 39.8 MB/s eta 0:00:00
# Downloading pynput-1.8.1-py2.py3-none-any.whl (91 kB)
# Downloading pyserial-3.5-py2.py3-none-any.whl (90 kB)
# Downloading rerun_sdk-0.22.1-cp38-abi3-manylinux_2_31_x86_64.whl (51.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.4/51.4 MB 35.7 MB/s eta 0:00:00
# Downloading termcolor-3.1.0-py3-none-any.whl (7.7 kB)
# Downloading torch-2.7.1-cp311-cp311-manylinux_2_28_x86_64.whl (821.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.2/821.2 MB 25.9 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (393.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.1/393.1 MB 35.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 111.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 157.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.7/897.7 kB 36.3 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl (571.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.0/571.0 MB 29.9 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (200.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.2/200.2 MB 62.9 MB/s eta 0:00:00
# Downloading nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 53.5 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 55.4 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (158.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.2/158.2 MB 65.2 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 MB 63.3 MB/s eta 0:00:00
# Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl (156.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 MB 64.1 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 MB 57.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 43.8 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# Downloading triton-3.3.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (155.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.7/155.7 MB 54.0 MB/s eta 0:00:00
# Downloading torchcodec-0.5-cp311-cp311-manylinux_2_28_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 58.7 MB/s eta 0:00:00
# Downloading torchvision-0.22.1-cp311-cp311-manylinux_2_28_x86_64.whl (7.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 87.1 MB/s eta 0:00:00
# Downloading wandb-0.21.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.4/22.4 MB 114.3 MB/s eta 0:00:00
# Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading click-8.2.1-py3-none-any.whl (102 kB)
# Downloading cloudpickle-3.1.1-py3-none-any.whl (20 kB)
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
# Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
# Downloading gitpython-3.1.45-py3-none-any.whl (208 kB)
# Downloading hf_transfer-0.1.9-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 112.9 MB/s eta 0:00:00
# Downloading hf_xet-1.1.9-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 104.6 MB/s eta 0:00:00
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23 kB)
# Downloading mergedeep-1.3.4-py3-none-any.whl (6.4 kB)
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
# Downloading numpy-2.2.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 121.4 MB/s eta 0:00:00
# Downloading orderly_set-5.5.0-py3-none-any.whl (13 kB)
# Downloading pillow-11.3.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 105.6 MB/s eta 0:00:00
# Downloading protobuf-6.32.0-cp39-abi3-manylinux2014_x86_64.whl (322 kB)
# Downloading pyarrow-21.0.0-cp311-cp311-manylinux_2_28_x86_64.whl (42.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 MB 41.5 MB/s eta 0:00:00
# Downloading pydantic-2.11.7-py3-none-any.whl (444 kB)
# Downloading pydantic_core-2.33.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 70.9 MB/s eta 0:00:00
# Downloading python_xlib-0.33-py2.py3-none-any.whl (182 kB)
# Downloading PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (762 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 763.0/763.0 kB 34.2 MB/s eta 0:00:00
# Downloading pyyaml_include-1.4.1-py3-none-any.whl (19 kB)
# Downloading regex-2025.7.34-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (798 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.9/798.9 kB 40.5 MB/s eta 0:00:00
# Downloading safetensors-0.6.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (485 kB)
# Downloading sentry_sdk-2.35.1-py2.py3-none-any.whl (363 kB)
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 139.0 MB/s eta 0:00:00
# Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Downloading filelock-3.19.1-py3-none-any.whl (15 kB)
# Downloading imageio_ffmpeg-0.6.0-py3-none-manylinux2014_x86_64.whl (29.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.5/29.5 MB 129.5 MB/s eta 0:00:00
# Downloading importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Downloading networkx-3.5-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 81.6 MB/s eta 0:00:00
# Downloading pandas-2.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 102.0 MB/s eta 0:00:00
# Downloading psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (277 kB)
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
# Downloading aiohttp-3.12.15-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 75.4 MB/s eta 0:00:00
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 22.8 MB/s eta 0:00:00
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading pfzy-0.3.4-py3-none-any.whl (8.5 kB)
# Downloading prompt_toolkit-3.0.52-py3-none-any.whl (391 kB)
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Downloading zipp-3.23.0-py3-none-any.whl (10 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading frozenlist-1.7.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (235 kB)
# Downloading multidict-6.6.4-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (246 kB)
# Downloading propcache-0.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (213 kB)
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Downloading yarl-1.20.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (348 kB)
# Downloading wcwidth-0.2.13-py2.py3-none-any.whl (34 kB)
# Building wheels for collected packages: lerobot, evdev
#   Building editable for lerobot (pyproject.toml) ... done
#   Created wheel for lerobot: filename=lerobot-0.3.4-0.editable-py3-none-any.whl size=15683 sha256=8dc073166d0abd87c73a1d2ff2de26a1b000f39d48d6aae80cf9b0e5d0cc606d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-g0rpmpwp/wheels/15/0d/02/b9c6ff1c78574dee99101ad231194b3425eb4cd784ce8c8338
#   Building wheel for evdev (pyproject.toml) ... done
#   Created wheel for evdev: filename=evdev-1.9.2-cp311-cp311-linux_x86_64.whl size=74951 sha256=738561fe1eb01207782ebd99e85309a355ebf7ee76dc777659d5fbc60e9542d9
#   Stored in directory: /root/.cache/pip/wheels/72/97/d0/ea1b02915719d1cdb6a8810aa7683524c7aceedc5812cdeed7
# Successfully built lerobot evdev
# Installing collected packages: wcwidth, pytz, pyserial, nvidia-cusparselt-cu12, mpmath, farama-notifications, zipp, xxhash, tzdata, typing-extensions, triton, torchcodec, toml, termcolor, sympy, smmap, six, sentry-sdk, safetensors, regex, pyyaml, pyarrow, psutil, protobuf, propcache, prompt-toolkit, Pillow, pfzy, orderly-set, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, mypy-extensions, multidict, mergedeep, markupsafe, itsdangerous, imageio-ffmpeg, hf-xet, hf-transfer, fsspec, frozenlist, filelock, evdev, einops, dill, cmake, cloudpickle, click, blinker, av, attrs, annotated-types, aiohappyeyeballs, yarl, werkzeug, typing-inspection, typing-inspect, rerun-sdk, pyyaml-include, python-xlib, python-dateutil, pydantic-core, opencv-python-headless, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, multiprocess, jsonlines, jinja2, InquirerPy, importlib_metadata, imageio, huggingface-hub, gymnasium, gitdb, deepdiff, aiosignal, pynput, pydantic, pandas, nvidia-cusolver-cu12, gitpython, flask, draccus, diffusers, aiohttp, wandb, torch, torchvision, datasets, lerobot
# Successfully installed InquirerPy-0.3.4 Pillow-11.3.0 aiohappyeyeballs-2.6.1 aiohttp-3.12.15 aiosignal-1.4.0 annotated-types-0.7.0 attrs-25.3.0 av-15.0.0 blinker-1.9.0 click-8.2.1 cloudpickle-3.1.1 cmake-4.1.0 datasets-3.6.0 deepdiff-8.6.0 diffusers-0.35.1 dill-0.3.8 draccus-0.10.0 einops-0.8.1 evdev-1.9.2 farama-notifications-0.0.4 filelock-3.19.1 flask-3.1.2 frozenlist-1.7.0 fsspec-2025.3.0 gitdb-4.0.12 gitpython-3.1.45 gymnasium-0.29.1 hf-transfer-0.1.9 hf-xet-1.1.9 huggingface-hub-0.34.4 imageio-2.37.0 imageio-ffmpeg-0.6.0 importlib_metadata-8.7.0 itsdangerous-2.2.0 jinja2-3.1.6 jsonlines-4.0.0 lerobot-0.3.4 markupsafe-3.0.2 mergedeep-1.3.4 mpmath-1.3.0 multidict-6.6.4 multiprocess-0.70.16 mypy-extensions-1.1.0 networkx-3.5 numpy-2.2.6 nvidia-cublas-cu12-12.6.4.1 nvidia-cuda-cupti-cu12-12.6.80 nvidia-cuda-nvrtc-cu12-12.6.77 nvidia-cuda-runtime-cu12-12.6.77 nvidia-cudnn-cu12-9.5.1.17 nvidia-cufft-cu12-11.3.0.4 nvidia-cufile-cu12-1.11.1.6 nvidia-curand-cu12-10.3.7.77 nvidia-cusolver-cu12-11.7.1.2 nvidia-cusparse-cu12-12.5.4.2 nvidia-cusparselt-cu12-0.6.3 nvidia-nccl-cu12-2.26.2 nvidia-nvjitlink-cu12-12.6.85 nvidia-nvtx-cu12-12.6.77 opencv-python-headless-4.12.0.88 orderly-set-5.5.0 pandas-2.3.2 pfzy-0.3.4 prompt-toolkit-3.0.52 propcache-0.3.2 protobuf-6.32.0 psutil-7.0.0 pyarrow-21.0.0 pydantic-2.11.7 pydantic-core-2.33.2 pynput-1.8.1 pyserial-3.5 python-dateutil-2.9.0.post0 python-xlib-0.33 pytz-2025.2 pyyaml-6.0.2 pyyaml-include-1.4.1 regex-2025.7.34 rerun-sdk-0.22.1 safetensors-0.6.2 sentry-sdk-2.35.1 six-1.17.0 smmap-5.0.2 sympy-1.14.0 termcolor-3.1.0 toml-0.10.2 torch-2.7.1 torchcodec-0.5 torchvision-0.22.1 triton-3.3.1 typing-extensions-4.15.0 typing-inspect-0.9.0 typing-inspection-0.4.1 tzdata-2025.2 wandb-0.21.1 wcwidth-0.2.13 werkzeug-3.1.3 xxhash-3.5.0 yarl-1.20.1 zipp-3.23.0

# %% [markdown]
# ## Weights & Biases login
# This cell logs you into Weights & Biases (wandb) to enable experiment tracking and logging.

# %%
# !wandb login
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: lichenglin0824 (lichenglin0824-nus) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %% [markdown]
# ## Start training ACT with LeRobot
#
# This cell runs the `train.py` script from the `lerobot` library to train a robot control policy.
#
# Make sure to adjust the following arguments to your setup:
#
# 1. `--dataset.repo_id=YOUR_HF_USERNAME/YOUR_DATASET`:
#    Replace this with the Hugging Face Hub repo ID where your dataset is stored, e.g., `pepijn223/il_gym0`.
#
# 2. `--policy.type=act`:
#    Specifies the policy configuration to use. `act` refers to [configuration_act.py](../lerobot/common/policies/act/configuration_act.py), which will automatically adapt to your dataset’s setup (e.g., number of motors and cameras).
#
# 3. `--output_dir=outputs/train/...`:
#    Directory where training logs and model checkpoints will be saved.
#
# 4. `--job_name=...`:
#    A name for this training job, used for logging and Weights & Biases.
#
# 5. `--policy.device=cuda`:
#    Use `cuda` if training on an NVIDIA GPU. Use `mps` for Apple Silicon, or `cpu` if no GPU is available.
#
# 6. `--wandb.enable=true`:
#    Enables Weights & Biases for visualizing training progress. You must be logged in via `wandb login` before running this.

# %%
# !cd lerobot && python /content/lerobot/src/lerobot/scripts/train.py \
  --dataset.repo_id=lichenglin0824/so100_pickplace_work2 \
  --policy.type=act \
  --output_dir=outputs/train/il_sim_test0 \
  --job_name=lichenglin_pickup_test \
  --policy.device=cuda \
  --wandb.enable=true \
  --policy.repo_id=lichenglin0824/so100_pickplace_trained_policy \
  --policy.push_to_hub=true
# Out:
# INFO 2025-08-28 12:16:25 ts/train.py:111 {'batch_size': 8,
#  'dataset': {'episodes': None,
#              'image_transforms': {'enable': False,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'brightness': {'kwargs': {'brightness': [0.8,
#                                                                                    1.2]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'contrast': {'kwargs': {'contrast': [0.8,
#                                                                                1.2]},
#                                                        'type': 'ColorJitter',
#                                                        'weight': 1.0},
#                                           'hue': {'kwargs': {'hue': [-0.05,
#                                                                      0.05]},
#                                                   'type': 'ColorJitter',
#                                                   'weight': 1.0},
#                                           'saturation': {'kwargs': {'saturation': [0.5,
#                                                                                    1.5]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'sharpness': {'kwargs': {'sharpness': [0.5,
#                                                                                  1.5]},
#                                                         'type': 'SharpnessJitter',
#                                                         'weight': 1.0}}},
#              'repo_id': 'lichenglin0824/so100_pickplace_work2',
#              'revision': None,
#              'root': None,
#              'use_imagenet_stats': True,
#              'video_backend': 'torchcodec'},
#  'env': None,
#  'eval': {'batch_size': 50, 'n_episodes': 50, 'use_async_envs': False},
#  'eval_freq': 20000,
#  'job_name': 'lichenglin_pickup_test',
#  'log_freq': 200,
#  'num_workers': 4,
#  'optimizer': {'betas': [0.9, 0.999],
#                'eps': 1e-08,
#                'grad_clip_norm': 10.0,
#                'lr': 1e-05,
#                'type': 'adamw',
#                'weight_decay': 0.0001},
#  'output_dir': 'outputs/train/il_sim_test0',
#  'policy': {'chunk_size': 100,
#             'device': 'cuda',
#             'dim_feedforward': 3200,
#             'dim_model': 512,
#             'dropout': 0.1,
#             'feedforward_activation': 'relu',
#             'input_features': {},
#             'kl_weight': 10.0,
#             'latent_dim': 32,
#             'license': None,
#             'n_action_steps': 100,
#             'n_decoder_layers': 1,
#             'n_encoder_layers': 4,
#             'n_heads': 8,
#             'n_obs_steps': 1,
#             'n_vae_encoder_layers': 4,
#             'normalization_mapping': {'ACTION': <NormalizationMode.MEAN_STD: 'MEAN_STD'>,
#                                       'STATE': <NormalizationMode.MEAN_STD: 'MEAN_STD'>,
#                                       'VISUAL': <NormalizationMode.MEAN_STD: 'MEAN_STD'>},
#             'optimizer_lr': 1e-05,
#             'optimizer_lr_backbone': 1e-05,
#             'optimizer_weight_decay': 0.0001,
#             'output_features': {},
#             'pre_norm': False,
#             'pretrained_backbone_weights': 'ResNet18_Weights.IMAGENET1K_V1',
#             'private': None,
#             'push_to_hub': True,
#             'replace_final_stride_with_dilation': False,
#             'repo_id': 'lichenglin0824/so100_pickplace_trained_policy',
#             'tags': None,
#             'temporal_ensemble_coeff': None,
#             'type': 'act',
#             'use_amp': False,
#             'use_vae': True,
#             'vision_backbone': 'resnet18'},
#  'resume': False,
#  'save_checkpoint': True,
#  'save_freq': 20000,
#  'scheduler': None,
#  'seed': 1000,
#  'steps': 100000,
#  'use_policy_training_preset': True,
#  'wandb': {'disable_artifact': False,
#            'enable': True,
#            'entity': None,
#            'mode': None,
#            'notes': None,
#            'project': 'lerobot',
#            'run_id': None}}
# Logs will be synced with wandb.
# INFO 2025-08-28 12:16:27 db_utils.py:103 Track this run --> https://wandb.ai/lichenglin0824-nus/lerobot/runs/6hjzuejb
# INFO 2025-08-28 12:16:27 ts/train.py:127 Creating dataset
# Fetching 4 files:   0% 0/4 [00:00<?, ?it/s]
# tasks.jsonl: 100% 49.0/49.0 [00:00<00:00, 199kB/s]
#
# episodes.jsonl: 0.00B [00:00, ?B/s]
#
# episodes_stats.jsonl: 65.7kB [00:00, 7.96MB/s]
# episodes.jsonl: 2.12kB [00:00, 45.1kB/s]
# Fetching 4 files:  25% 1/4 [00:00<00:02,  1.22it/s]
# info.json: 3.22kB [00:00, 9.22MB/s]
# Fetching 4 files: 100% 4/4 [00:00<00:00,  4.50it/s]
# Fetching 96 files:   0% 0/96 [00:00<?, ?it/s]
# data/chunk-000/episode_000001.parquet:   0% 0.00/37.9k [00:00<?, ?B/s]
#
# data/chunk-000/episode_000002.parquet:   0% 0.00/36.7k [00:00<?, ?B/s]
#
#
# data/chunk-000/episode_000004.parquet:   0% 0.00/37.2k [00:00<?, ?B/s]
#
#
#
# data/chunk-000/episode_000000.parquet:   0% 0.00/32.2k [00:00<?, ?B/s]
#
#
#
#
# data/chunk-000/episode_000003.parquet:   0% 0.00/35.4k [00:00<?, ?B/s]
#
#
#
#
#
# data/chunk-000/episode_000005.parquet:   0% 0.00/32.2k [00:00<?, ?B/s]
#
#
#
#
#
#
# .gitattributes: 2.46kB [00:00, 7.87MB/s]
# Fetching 96 files:   1% 1/96 [00:00<01:18,  1.20it/s]
#
#
#
#
#
#
# README.md: 3.71kB [00:00, 10.1MB/s]
# Fetching 96 files:   2% 2/96 [00:01<00:49,  1.89it/s]
#
#
#
#
#
#
# data/chunk-000/episode_000006.parquet:   0% 0.00/38.8k [00:00<?, ?B/s]
#
#
#
#
#
#
#
# data/chunk-000/episode_000007.parquet:   0% 0.00/37.7k [00:00<?, ?B/s]
# data/chunk-000/episode_000001.parquet: 100% 37.9k/37.9k [00:01<00:00, 27.7kB/s]
#
#
#
#
#
#
# data/chunk-000/episode_000005.parquet: 100% 32.2k/32.2k [00:01<00:00, 23.8kB/s]
#
#
#
#
# data/chunk-000/episode_000000.parquet: 100% 32.2k/32.2k [00:01<00:00, 23.7kB/s]
# Fetching 96 files:   3% 3/96 [00:01<00:59,  1.56it/s]
#
#
# data/chunk-000/episode_000004.parquet: 100% 37.2k/37.2k [00:01<00:00, 26.9kB/s]
#
#
# data/chunk-000/episode_000002.parquet: 100% 36.7k/36.7k [00:01<00:00, 25.5kB/s]
#
#
#
#
#
# data/chunk-000/episode_000003.parquet: 100% 35.4k/35.4k [00:01<00:00, 22.5kB/s]
# Fetching 96 files:   6% 6/96 [00:02<00:23,  3.80it/s]
#
#
#
#
#
#
# data/chunk-000/episode_000006.parquet: 100% 38.8k/38.8k [00:00<00:00, 44.9kB/s]
#
# data/chunk-000/episode_000010.parquet:   0% 0.00/41.2k [00:00<?, ?B/s]
#
# data/chunk-000/episode_000009.parquet:   0% 0.00/39.7k [00:00<?, ?B/s]
#
#
#
#
#
#
#
# data/chunk-000/episode_000007.parquet: 100% 37.7k/37.7k [00:00<00:00, 51.8kB/s]
# Fetching 96 files:  10% 10/96 [00:02<00:13,  6.22it/s]
#
#
# data/chunk-000/episode_000012.parquet:   0% 0.00/37.6k [00:00<?, ?B/s]
#
#
#
# data/chunk-000/episode_000008.parquet:   0% 0.00/37.7k [00:00<?, ?B/s]
#
#
#
#
# data/chunk-000/episode_000011.parquet:   0% 0.00/37.7k [00:00<?, ?B/s]
#
#
#
#
#
# data/chunk-000/episode_000013.parquet:   0% 0.00/37.2k [00:00<?, ?B/s]
#
#
#
#
#
#
# data/chunk-000/episode_000014.parquet:   0% 0.00/35.3k [00:00<?, ?B/s]
# data/chunk-000/episode_000010.parquet: 100% 41.2k/41.2k [00:00<00:00, 81.7kB/s]
#
#
# data/chunk-000/episode_000009.parquet: 100% 39.7k/39.7k [00:00<00:00, 82.1kB/s]
#
# data/chunk-000/episode_000015.parquet:   0% 0.00/38.7k [00:00<?, ?B/s]
#
#
# data/chunk-000/episode_000012.parquet: 100% 37.6k/37.6k [00:00<00:00, 74.2kB/s]
#
#
#
#
#
# data/chunk-000/episode_000011.parquet: 100% 37.7k/37.7k [00:00<00:00, 74.5kB/s]
#
#
#
#
# data/chunk-000/episode_000008.parquet: 100% 37.7k/37.7k [00:00<00:00, 72.7kB/s]
# Fetching 96 files:  11% 11/96 [00:03<00:19,  4.36it/s]
#
#
#
#
#
# data/chunk-000/episode_000013.parquet: 100% 37.2k/37.2k [00:00<00:00, 78.8kB/s]
#
#
#
#
#
#
#
# data/chunk-000/episode_000014.parquet: 100% 35.3k/35.3k [00:00<00:00, 69.3kB/s]
# Fetching 96 files:  18% 17/96 [00:03<00:08,  9.08it/s]
#
# data/chunk-000/episode_000016.parquet:   0% 0.00/40.3k [00:00<?, ?B/s]
# data/chunk-000/episode_000015.parquet: 100% 38.7k/38.7k [00:00<00:00, 76.7kB/s]
#
# data/chunk-000/episode_000018.parquet:   0% 0.00/41.8k [00:00<?, ?B/s]
#
#
# data/chunk-000/episode_000017.parquet:   0% 0.00/40.6k [00:00<?, ?B/s]
#
#
#
# data/chunk-000/episode_000020.parquet:   0% 0.00/39.5k [00:00<?, ?B/s]
#
#
#
#
# data/chunk-000/episode_000021.parquet:   0% 0.00/38.4k [00:00<?, ?B/s]
#
#
#
#
#
# data/chunk-000/episode_000019.parquet:   0% 0.00/35.1k [00:00<?, ?B/s]
#
#
#
#
#
#
# data/chunk-000/episode_000022.parquet:   0% 0.00/39.1k [00:00<?, ?B/s]
#
# data/chunk-000/episode_000016.parquet: 100% 40.3k/40.3k [00:00<00:00, 82.4kB/s]
# Fetching 96 files:  20% 19/96 [00:03<00:12,  6.08it/s]
#
# data/chunk-000/episode_000023.parquet:   0% 0.00/31.3k [00:00<?, ?B/s]
# data/chunk-000/episode_000018.parquet: 100% 41.8k/41.8k [00:00<00:00, 81.3kB/s]
#
#
#
# data/chunk-000/episode_000017.parquet: 100% 40.6k/40.6k [00:00<00:00, 82.4kB/s]
# Fetching 96 files:  22% 21/96 [00:04<00:10,  6.88it/s]
#
#
#
#
# data/chunk-000/episode_000021.parquet: 100% 38.4k/38.4k [00:00<00:00, 79.6kB/s]
#
#
#
#
# data/chunk-000/episode_000020.parquet: 100% 39.5k/39.5k [00:00<00:00, 77.0kB/s]
#
#
#
#
#
#
# data/chunk-000/episode_000019.parquet: 100% 35.1k/35.1k [00:00<00:00, 69.9kB/s]
# Fetching 96 files:  24% 23/96 [00:04<00:09,  8.09it/s]
#
#
#
#
#
#
# data/chunk-000/episode_000022.parquet: 100% 39.1k/39.1k [00:00<00:00, 83.3kB/s]
#
# data/chunk-000/episode_000024.parquet:   0% 0.00/40.9k [00:00<?, ?B/s]
#
# data/chunk-000/episode_000023.parquet: 100% 31.3k/31.3k [00:00<00:00, 63.5kB/s]
# Fetching 96 files:  27% 26/96 [00:04<00:07,  9.05it/s]
#
# data/chunk-000/episode_000025.parquet:   0% 0.00/40.9k [00:00<?, ?B/s]
#
#
# data/chunk-000/episode_000026.parquet:   0% 0.00/34.3k [00:00<?, ?B/s]
#
#
#
# data/chunk-000/episode_000027.parquet:   0% 0.00/32.2k [00:00<?, ?B/s]
#
#
#
#
# data/chunk-000/episode_000028.parquet:   0% 0.00/38.4k [00:00<?, ?B/s]
#
#
#
#
#
# data/chunk-000/episode_000029.parquet:   0% 0.00/37.5k [00:00<?, ?B/s]
#
#
#
#
#
#
# videos/chunk-000/observation.images.fron(…):   0% 0.00/3.16M [00:00<?, ?B/s]
# data/chunk-000/episode_000024.parquet: 100% 40.9k/40.9k [00:00<00:00, 80.4kB/s]
#
# videos/chunk-000/observation.images.fron(…):   0% 0.00/3.44M [00:00<?, ?B/s]
#
# data/chunk-000/episode_000025.parquet: 100% 40.9k/40.9k [00:00<00:00, 82.3kB/s]
# Fetching 96 files:  29% 28/96 [00:04<00:10,  6.59it/s]
#
#
#
# data/chunk-000/episode_000027.parquet: 100% 32.2k/32.2k [00:00<00:00, 66.5kB/s]
#
#
#
# data/chunk-000/episode_000026.parquet: 100% 34.3k/34.3k [00:00<00:00, 67.1kB/s]
#
#
#
#
#
# data/chunk-000/episode_000028.parquet: 100% 38.4k/38.4k [00:00<00:00, 78.8kB/s]
#
#
#
#
#
#
# data/chunk-000/episode_000029.parquet: 100% 37.5k/37.5k [00:00<00:00, 75.8kB/s]
# Fetching 96 files:  33% 32/96 [00:05<00:06,  9.42it/s]
#
#
#
#
#
#
# videos/chunk-000/observation.images.fron(…): 100% 3.16M/3.16M [00:00<00:00, 6.20MB/s]
#
#
# videos/chunk-000/observation.images.fron(…):   0% 0.00/3.34M [00:00<?, ?B/s]
# videos/chunk-000/observation.images.fron(…): 100% 3.44M/3.44M [00:00<00:00, 6.95MB/s]
# Fetching 96 files:  40% 38/96 [00:05<00:04, 13.18it/s]
# videos/chunk-000/observation.images.fron(…):   0% 0.00/3.07M [00:00<?, ?B/s]
#
#
# videos/chunk-000/observation.images.fron(…):   0% 0.00/3.14M [00:00<?, ?B/s]
#
#
#
# videos/chunk-000/observation.images.fron(…):   0% 0.00/3.31M [00:00<?, ?B/s]
#
#
#
#
# videos/chunk-000/observation.images.fron(…):   0% 0.00/3.08M [00:00<?, ?B/s]
#
#
#
#
#
# videos/chunk-000/observation.images.fron(…):   0% 0.00/3.23M [00:00<?, ?B/s]
#
#
#
#
#
#
# videos/chunk-000/observation.images.fron(…):   0% 0.00/3.29M [00:00<?, ?B/s]
#
# videos/chunk-000/observation.images.fron(…): 100% 3.34M/3.34M [00:00<00:00, 7.15MB/s]
#
# videos/chunk-000/observation.images.fron(…): 100% 3.07M/3.07M [00:00<00:00, 6.30MB/s]
# Fetching 96 files:  42% 40/96 [00:05<00:06,  8.88it/s]
# videos/chunk-000/observation.images.fron(…):   0% 0.00/3.09M [00:00<?, ?B/s]
#
#
# videos/chunk-000/observation.images.fron(…): 100% 3.14M/3.14M [00:00<00:00, 6.08MB/s]
#
#
#
#
#
# videos/chunk-000/observation.images.fron(…): 100% 3.08M/3.08M [00:00<00:00, 6.33MB/s]
#
#
#
#
# videos/chunk-000/observation.images.fron(…): 100% 3.31M/3.31M [00:00<00:00, 6.41MB/s]
# Fetching 96 files:  44% 42/96 [00:06<00:05, 10.04it/s]
#
#
#
#
#
# videos/chunk-000/observation.images.fron(…): 100% 3.23M/3.23M [00:00<00:00, 6.48MB/s]
#
#
#
#
#
#
#
# videos/chunk-000/observation.images.fron(…): 100% 3.29M/3.29M [00:00<00:00, 6.94MB/s]
# Fetching 96 files:  47% 45/96 [00:06<00:04, 11.60it/s]
#
# videos/chunk-000/observation.images.fron(…):   0% 0.00/2.99M [00:00<?, ?B/s]
#
#
# videos/chunk-000/observation.images.fron(…):   0% 0.00/3.20M [00:00<?, ?B/s]
# videos/chunk-000/observation.images.fron(…): 100% 3.09M/3.09M [00:00<00:00, 6.50MB/s]
#
# videos/chunk-000/observation.images.fron(…):   0% 0.00/3.06M [00:00<?, ?B/s]
#
#
#
# videos/chunk-000/observation.images.fron(…):   0% 0.00/3.32M [00:00<?, ?B/s]
#
#
#
#
# videos/chunk-000/observation.images.fron(…):   0% 0.00/3.11M [00:00<?, ?B/s]
#
#
#
#
#
# videos/chunk-000/observation.images.fron(…):   0% 0.00/3.41M [00:00<?, ?B/s]
#
#
#
#
#
#
# videos/chunk-000/observation.images.fron(…):   0% 0.00/3.36M [00:00<?, ?B/s]
#
# videos/chunk-000/observation.images.fron(…): 100% 2.99M/2.99M [00:00<00:00, 6.31MB/s]
# Fetching 96 files:  49% 47/96 [00:06<00:06,  7.46it/s]
#
#
# videos/chunk-000/observation.images.fron(…): 100% 3.20M/3.20M [00:00<00:00, 6.46MB/s]
#
#
# videos/chunk-000/observation.images.fron(…):   0% 0.00/3.35M [00:00<?, ?B/s]
# videos/chunk-000/observation.images.fron(…): 100% 3.06M/3.06M [00:00<00:00, 6.45MB/s]
#
#
#
#
# videos/chunk-000/observation.images.fron(…): 100% 3.32M/3.32M [00:00<00:00, 7.09MB/s]
#
#
#
#
#
# videos/chunk-000/observation.images.fron(…): 100% 3.11M/3.11M [00:00<00:00, 5.93MB/s]
# Fetching 96 files:  51% 49/96 [00:07<00:06,  7.33it/s]
#
#
#
#
#
# videos/chunk-000/observation.images.fron(…): 100% 3.41M/3.41M [00:00<00:00, 7.21MB/s]
#
#
#
#
#
#
#
# videos/chunk-000/observation.images.fron(…): 100% 3.36M/3.36M [00:00<00:00, 7.06MB/s]
#
# videos/chunk-000/observation.images.fron(…):   0% 0.00/3.34M [00:00<?, ?B/s]
#
#
# videos/chunk-000/observation.images.fron(…):   0% 0.00/2.93M [00:00<?, ?B/s]
#
# videos/chunk-000/observation.images.fron(…): 100% 3.35M/3.35M [00:00<00:00, 6.66MB/s]
# Fetching 96 files:  56% 54/96 [00:07<00:04,  9.24it/s]
#
# videos/chunk-000/observation.images.fron(…):   0% 0.00/3.07M [00:00<?, ?B/s]
#
#
#
# videos/chunk-000/observation.images.fron(…):   0% 0.00/3.03M [00:00<?, ?B/s]
#
#
#
#
# videos/chunk-000/observation.images.fron(…):   0% 0.00/3.05M [00:00<?, ?B/s]
#
#
#
#
#
# videos/chunk-000/observation.images.fron(…):   0% 0.00/3.04M [00:00<?, ?B/s]
# videos/chunk-000/observation.images.fron(…): 100% 3.34M/3.34M [00:00<00:00, 6.70MB/s]
#
#
#
# videos/chunk-000/observation.images.fron(…): 100% 2.93M/2.93M [00:00<00:00, 5.92MB/s]
# Fetching 96 files:  58% 56/96 [00:07<00:05,  7.44it/s]
# videos/chunk-000/observation.images.fron(…):   0% 0.00/2.97M [00:00<?, ?B/s]
#
#
# videos/chunk-000/observation.images.fron(…):   0% 0.00/2.98M [00:00<?, ?B/s]
#
# videos/chunk-000/observation.images.fron(…): 100% 3.07M/3.07M [00:00<00:00, 4.88MB/s]
# Fetching 96 files:  59% 57/96 [00:08<00:05,  7.12it/s]
#
#
#
#
#
# videos/chunk-000/observation.images.fron(…): 100% 3.04M/3.04M [00:00<00:00, 5.83MB/s]
#
#
#
#
# videos/chunk-000/observation.images.fron(…): 100% 3.03M/3.03M [00:00<00:00, 4.80MB/s]
#
#
#
#
#
# videos/chunk-000/observation.images.fron(…): 100% 3.05M/3.05M [00:00<00:00, 5.37MB/s]
#
#
# videos/chunk-000/observation.images.fron(…):   0% 0.00/2.96M [00:00<?, ?B/s]
#
#
#
# videos/chunk-000/observation.images.fron(…):   0% 0.00/3.00M [00:00<?, ?B/s]
# videos/chunk-000/observation.images.fron(…): 100% 2.97M/2.97M [00:00<00:00, 5.83MB/s]
#
# videos/chunk-000/observation.images.fron(…):   0% 0.00/3.07M [00:00<?, ?B/s]
#
#
#
#
# videos/chunk-000/observation.images.side(…):   0% 0.00/5.46M [00:00<?, ?B/s]
#
#
#
#
#
# videos/chunk-000/observation.images.side(…):   0% 0.00/5.66M [00:00<?, ?B/s]
#
#
#
#
#
#
# videos/chunk-000/observation.images.fron(…):   0% 0.00/3.33M [00:00<?, ?B/s]
#
#
# videos/chunk-000/observation.images.fron(…): 100% 2.98M/2.98M [00:00<00:00, 4.59MB/s]
# Fetching 96 files:  64% 61/96 [00:08<00:05,  6.69it/s]
#
# videos/chunk-000/observation.images.fron(…): 100% 2.96M/2.96M [00:00<00:00, 6.05MB/s]
#
#
#
#
# videos/chunk-000/observation.images.fron(…): 100% 3.00M/3.00M [00:00<00:00, 5.91MB/s]
# Fetching 96 files:  67% 64/96 [00:08<00:03,  8.27it/s]
#
# videos/chunk-000/observation.images.side(…):   0% 0.00/5.57M [00:00<?, ?B/s]
#
#
#
#
# videos/chunk-000/observation.images.side(…): 100% 5.46M/5.46M [00:00<00:00, 11.1MB/s]
#
# videos/chunk-000/observation.images.fron(…): 100% 3.07M/3.07M [00:00<00:00, 6.03MB/s]
#
#
#
#
#
#
# videos/chunk-000/observation.images.side(…): 100% 5.66M/5.66M [00:00<00:00, 12.0MB/s]
#
#
#
#
#
#
#
# videos/chunk-000/observation.images.fron(…): 100% 3.33M/3.33M [00:00<00:00, 6.72MB/s]
# Fetching 96 files:  69% 66/96 [00:09<00:03,  8.26it/s]
# videos/chunk-000/observation.images.side(…):   0% 0.00/5.50M [00:00<?, ?B/s]
#
#
# videos/chunk-000/observation.images.side(…):   0% 0.00/5.34M [00:00<?, ?B/s]
#
#
#
# videos/chunk-000/observation.images.side(…):   0% 0.00/5.48M [00:00<?, ?B/s]
#
# videos/chunk-000/observation.images.side(…): 100% 5.57M/5.57M [00:00<00:00, 11.1MB/s]
# Fetching 96 files:  72% 69/96 [00:09<00:03,  8.64it/s]
#
# videos/chunk-000/observation.images.side(…):   0% 0.00/5.45M [00:00<?, ?B/s]
#
#
#
#
# videos/chunk-000/observation.images.side(…):   0% 0.00/5.32M [00:00<?, ?B/s]
#
#
#
#
#
# videos/chunk-000/observation.images.side(…):   0% 0.00/5.36M [00:00<?, ?B/s]
#
#
#
#
#
#
# videos/chunk-000/observation.images.side(…):   0% 0.00/5.58M [00:00<?, ?B/s]
# videos/chunk-000/observation.images.side(…): 100% 5.50M/5.50M [00:00<00:00, 11.0MB/s]
# Fetching 96 files:  73% 70/96 [00:09<00:03,  7.40it/s]
#
#
# videos/chunk-000/observation.images.side(…): 100% 5.34M/5.34M [00:00<00:00, 10.7MB/s]
#
#
#
# videos/chunk-000/observation.images.side(…): 100% 5.34M/5.34M [00:00<00:00, 10.7MB/s]
# videos/chunk-000/observation.images.side(…): 100% 5.48M/5.48M [00:00<00:00, 11.3MB/s]
# Fetching 96 files:  74% 71/96 [00:09<00:03,  7.24it/s]
# videos/chunk-000/observation.images.side(…):   0% 0.00/5.32M [00:00<?, ?B/s]
#
#
#
#
# videos/chunk-000/observation.images.side(…): 100% 5.32M/5.32M [00:00<00:00, 9.16MB/s]
#
#
#
#
#
#
#
# videos/chunk-000/observation.images.side(…): 100% 5.58M/5.58M [00:00<00:00, 10.2MB/s]
#
#
#
# videos/chunk-000/observation.images.side(…):   0% 0.00/5.36M [00:00<?, ?B/s]
#
#
#
#
#
# videos/chunk-000/observation.images.side(…): 100% 5.36M/5.36M [00:00<00:00, 8.49MB/s]
#
#
# videos/chunk-000/observation.images.side(…): 100% 5.45M/5.45M [00:00<00:00, 8.07MB/s]
# Fetching 96 files:  76% 73/96 [00:10<00:03,  6.61it/s]
#
# videos/chunk-000/observation.images.side(…):   0% 0.00/5.34M [00:00<?, ?B/s]
#
#
#
# videos/chunk-000/observation.images.side(…):   0% 0.00/5.37M [00:00<?, ?B/s]
# videos/chunk-000/observation.images.side(…): 100% 5.32M/5.32M [00:00<00:00, 9.56MB/s]
# Fetching 96 files:  80% 77/96 [00:10<00:02,  8.90it/s]
# videos/chunk-000/observation.images.side(…):   0% 0.00/5.45M [00:00<?, ?B/s]
#
#
#
#
# videos/chunk-000/observation.images.side(…):   0% 0.00/5.71M [00:00<?, ?B/s]
#
#
# videos/chunk-000/observation.images.side(…): 100% 5.36M/5.36M [00:00<00:00, 10.8MB/s]
# Fetching 96 files:  81% 78/96 [00:10<00:02,  7.88it/s]
#
#
# videos/chunk-000/observation.images.side(…):   0% 0.00/5.77M [00:00<?, ?B/s]
#
#
#
#
#
# videos/chunk-000/observation.images.side(…):   0% 0.00/5.65M [00:00<?, ?B/s]
#
#
#
# videos/chunk-000/observation.images.side(…): 100% 5.37M/5.37M [00:00<00:00, 10.9MB/s]
#
#
# videos/chunk-000/observation.images.side(…): 100% 5.34M/5.34M [00:00<00:00, 10.6MB/s]
# Fetching 96 files:  82% 79/96 [00:10<00:02,  7.66it/s]
#
# videos/chunk-000/observation.images.side(…):   0% 0.00/5.64M [00:00<?, ?B/s]
# videos/chunk-000/observation.images.side(…): 100% 5.45M/5.45M [00:00<00:00, 10.7MB/s]
# Fetching 96 files:  84% 81/96 [00:11<00:02,  7.37it/s]
#
#
#
#
# videos/chunk-000/observation.images.side(…): 100% 5.71M/5.71M [00:00<00:00, 11.4MB/s]
#
# videos/chunk-000/observation.images.side(…):   0% 0.00/5.14M [00:00<?, ?B/s]
#
#
# videos/chunk-000/observation.images.side(…): 100% 5.77M/5.77M [00:00<00:00, 11.1MB/s]
# Fetching 96 files:  86% 83/96 [00:11<00:01,  9.15it/s]
#
#
#
#
#
# videos/chunk-000/observation.images.side(…): 100% 5.65M/5.65M [00:00<00:00, 12.0MB/s]
#
#
#
# videos/chunk-000/observation.images.side(…):   0% 0.00/5.34M [00:00<?, ?B/s]
#
#
#
# videos/chunk-000/observation.images.side(…):   0% 0.00/5.23M [00:00<?, ?B/s]
#
#
#
#
# videos/chunk-000/observation.images.side(…):   0% 0.00/5.27M [00:00<?, ?B/s]
#
# videos/chunk-000/observation.images.side(…): 100% 5.64M/5.64M [00:00<00:00, 8.47MB/s]
# Fetching 96 files:  89% 85/96 [00:11<00:01,  7.20it/s]
#
# videos/chunk-000/observation.images.side(…):   0% 0.00/5.15M [00:00<?, ?B/s]
#
#
#
#
#
# videos/chunk-000/observation.images.side(…):   0% 0.00/5.53M [00:00<?, ?B/s]
# videos/chunk-000/observation.images.side(…): 100% 5.14M/5.14M [00:00<00:00, 9.30MB/s]
#
# videos/chunk-000/observation.images.side(…):   0% 0.00/5.32M [00:00<?, ?B/s]
#
#
#
# videos/chunk-000/observation.images.side(…): 100% 5.23M/5.23M [00:00<00:00, 10.2MB/s]
#
#
#
# videos/chunk-000/observation.images.side(…): 100% 5.34M/5.34M [00:00<00:00, 10.0MB/s]
# Fetching 96 files:  91% 87/96 [00:11<00:01,  7.73it/s]
#
#
#
#
# videos/chunk-000/observation.images.side(…): 100% 5.27M/5.27M [00:00<00:00, 10.5MB/s]
# Fetching 96 files:  93% 89/96 [00:12<00:00,  7.60it/s]
#
#
# videos/chunk-000/observation.images.side(…):   0% 0.00/5.19M [00:00<?, ?B/s]
#
# videos/chunk-000/observation.images.side(…): 100% 5.15M/5.15M [00:00<00:00, 10.2MB/s]
#
#
#
#
#
#
# videos/chunk-000/observation.images.side(…): 100% 5.53M/5.53M [00:00<00:00, 10.9MB/s]
# Fetching 96 files:  95% 91/96 [00:12<00:00,  9.26it/s]
# videos/chunk-000/observation.images.side(…): 100% 5.32M/5.32M [00:00<00:00, 10.6MB/s]
#
# videos/chunk-000/observation.images.side(…):   0% 0.00/5.21M [00:00<?, ?B/s]
#
# videos/chunk-000/observation.images.side(…):   0% 0.00/5.34M [00:00<?, ?B/s]
#
#
#
# videos/chunk-000/observation.images.side(…):   0% 0.00/5.35M [00:00<?, ?B/s]
#
#
# videos/chunk-000/observation.images.side(…): 100% 5.19M/5.19M [00:00<00:00, 11.0MB/s]
# Fetching 96 files:  97% 93/96 [00:12<00:00,  7.62it/s]
# videos/chunk-000/observation.images.side(…): 100% 5.21M/5.21M [00:00<00:00, 10.6MB/s]
# Fetching 96 files:  98% 94/96 [00:12<00:00,  6.57it/s]
#
# videos/chunk-000/observation.images.side(…): 100% 5.34M/5.34M [00:00<00:00, 10.8MB/s]
#
#
#
#
# videos/chunk-000/observation.images.side(…): 100% 5.35M/5.35M [00:00<00:00, 10.4MB/s]
# Fetching 96 files: 100% 96/96 [00:13<00:00,  7.36it/s]
# Resolving data files: 100% 30/30 [00:00<00:00, 86007.60it/s]
# Downloading data: 100% 30/30 [00:00<00:00, 48639.01files/s]
# Generating train split: 23445 examples [00:00, 322764.79 examples/s]
# INFO 2025-08-28 12:16:43 ts/train.py:138 Creating policy
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100% 44.7M/44.7M [00:00<00:00, 182MB/s]
# INFO 2025-08-28 12:16:44 ts/train.py:144 Creating optimizer and scheduler
# INFO 2025-08-28 12:16:44 ts/train.py:156 Output dir: outputs/train/il_sim_test0
# INFO 2025-08-28 12:16:44 ts/train.py:159 cfg.steps=100000 (100K)
# INFO 2025-08-28 12:16:44 ts/train.py:160 dataset.num_frames=23445 (23K)
# INFO 2025-08-28 12:16:44 ts/train.py:161 dataset.num_episodes=30
# INFO 2025-08-28 12:16:44 ts/train.py:162 num_learnable_params=51597190 (52M)
# INFO 2025-08-28 12:16:44 ts/train.py:163 num_total_params=51597238 (52M)
# /usr/local/lib/python3.11/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# INFO 2025-08-28 12:16:44 ts/train.py:202 Start offline training on a fixed dataset
# INFO 2025-08-28 12:18:38 ts/train.py:232 step:200 smpl:2K ep:2 epch:0.07 loss:6.485 grdn:154.164 lr:1.0e-05 updt_s:0.554 data_s:0.013
# INFO 2025-08-28 12:20:32 ts/train.py:232 step:400 smpl:3K ep:4 epch:0.14 loss:2.842 grdn:86.379 lr:1.0e-05 updt_s:0.567 data_s:0.002
# INFO 2025-08-28 12:22:26 ts/train.py:232 step:600 smpl:5K ep:6 epch:0.20 loss:2.399 grdn:74.320 lr:1.0e-05 updt_s:0.567 data_s:0.002
# INFO 2025-08-28 12:24:20 ts/train.py:232 step:800 smpl:6K ep:8 epch:0.27 loss:2.130 grdn:69.243 lr:1.0e-05 updt_s:0.567 data_s:0.002
# INFO 2025-08-28 12:26:14 ts/train.py:232 step:1K smpl:8K ep:10 epch:0.34 loss:1.889 grdn:64.990 lr:1.0e-05 updt_s:0.568 data_s:0.002
# INFO 2025-08-28 12:28:08 ts/train.py:232 step:1K smpl:10K ep:12 epch:0.41 loss:1.675 grdn:60.829 lr:1.0e-05 updt_s:0.567 data_s:0.002
# INFO 2025-08-28 12:30:03 ts/train.py:232 step:1K smpl:11K ep:14 epch:0.48 loss:1.552 grdn:59.599 lr:1.0e-05 updt_s:0.569 data_s:0.002
# INFO 2025-08-28 12:31:57 ts/train.py:232 step:2K smpl:13K ep:16 epch:0.55 loss:1.377 grdn:55.171 lr:1.0e-05 updt_s:0.568 data_s:0.002
# INFO 2025-08-28 12:33:51 ts/train.py:232 step:2K smpl:14K ep:18 epch:0.61 loss:1.264 grdn:53.050 lr:1.0e-05 updt_s:0.567 data_s:0.002
# INFO 2025-08-28 12:35:45 ts/train.py:232 step:2K smpl:16K ep:20 epch:0.68 loss:1.162 grdn:51.358 lr:1.0e-05 updt_s:0.566 data_s:0.002
# INFO 2025-08-28 12:37:39 ts/train.py:232 step:2K smpl:18K ep:23 epch:0.75 loss:1.042 grdn:47.558 lr:1.0e-05 updt_s:0.567 data_s:0.002
# INFO 2025-08-28 12:39:33 ts/train.py:232 step:2K smpl:19K ep:25 epch:0.82 loss:0.953 grdn:46.959 lr:1.0e-05 updt_s:0.567 data_s:0.002
# INFO 2025-08-28 12:41:27 ts/train.py:232 step:3K smpl:21K ep:27 epch:0.89 loss:0.850 grdn:43.248 lr:1.0e-05 updt_s:0.568 data_s:0.002
# INFO 2025-08-28 12:43:21 ts/train.py:232 step:3K smpl:22K ep:29 epch:0.96 loss:0.772 grdn:40.670 lr:1.0e-05 updt_s:0.569 data_s:0.002
# INFO 2025-08-28 12:45:20 ts/train.py:232 step:3K smpl:24K ep:31 epch:1.02 loss:0.690 grdn:38.537 lr:1.0e-05 updt_s:0.583 data_s:0.008
# INFO 2025-08-28 12:47:14 ts/train.py:232 step:3K smpl:26K ep:33 epch:1.09 loss:0.642 grdn:37.188 lr:1.0e-05 updt_s:0.568 data_s:0.002
# INFO 2025-08-28 12:49:08 ts/train.py:232 step:3K smpl:27K ep:35 epch:1.16 loss:0.574 grdn:34.812 lr:1.0e-05 updt_s:0.568 data_s:0.002
# INFO 2025-08-28 12:51:02 ts/train.py:232 step:4K smpl:29K ep:37 epch:1.23 loss:0.530 grdn:33.445 lr:1.0e-05 updt_s:0.568 data_s:0.002
# INFO 2025-08-28 12:52:56 ts/train.py:232 step:4K smpl:30K ep:39 epch:1.30 loss:0.485 grdn:32.475 lr:1.0e-05 updt_s:0.568 data_s:0.002
# INFO 2025-08-28 12:54:51 ts/train.py:232 step:4K smpl:32K ep:41 epch:1.36 loss:0.446 grdn:31.104 lr:1.0e-05 updt_s:0.570 data_s:0.002
# INFO 2025-08-28 12:56:46 ts/train.py:232 step:4K smpl:34K ep:43 epch:1.43 loss:0.423 grdn:30.210 lr:1.0e-05 updt_s:0.569 data_s:0.002
# INFO 2025-08-28 12:58:40 ts/train.py:232 step:4K smpl:35K ep:45 epch:1.50 loss:0.389 grdn:27.874 lr:1.0e-05 updt_s:0.568 data_s:0.002
# INFO 2025-08-28 13:00:34 ts/train.py:232 step:5K smpl:37K ep:47 epch:1.57 loss:0.354 grdn:26.455 lr:1.0e-05 updt_s:0.566 data_s:0.002
# INFO 2025-08-28 13:02:28 ts/train.py:232 step:5K smpl:38K ep:49 epch:1.64 loss:0.342 grdn:25.768 lr:1.0e-05 updt_s:0.568 data_s:0.002
# INFO 2025-08-28 13:04:22 ts/train.py:232 step:5K smpl:40K ep:51 epch:1.71 loss:0.317 grdn:25.044 lr:1.0e-05 updt_s:0.567 data_s:0.002
# INFO 2025-08-28 13:06:16 ts/train.py:232 step:5K smpl:42K ep:53 epch:1.77 loss:0.305 grdn:24.013 lr:1.0e-05 updt_s:0.569 data_s:0.002
# INFO 2025-08-28 13:08:10 ts/train.py:232 step:5K smpl:43K ep:55 epch:1.84 loss:0.288 grdn:22.887 lr:1.0e-05 updt_s:0.568 data_s:0.001
# INFO 2025-08-28 13:10:04 ts/train.py:232 step:6K smpl:45K ep:57 epch:1.91 loss:0.277 grdn:22.677 lr:1.0e-05 updt_s:0.567 data_s:0.002
# INFO 2025-08-28 13:11:59 ts/train.py:232 step:6K smpl:46K ep:59 epch:1.98 loss:0.263 grdn:22.382 lr:1.0e-05 updt_s:0.568 data_s:0.002
# INFO 2025-08-28 13:13:54 ts/train.py:232 step:6K smpl:48K ep:61 epch:2.05 loss:0.255 grdn:22.182 lr:1.0e-05 updt_s:0.567 data_s:0.010
# INFO 2025-08-28 13:15:49 ts/train.py:232 step:6K smpl:50K ep:63 epch:2.12 loss:0.245 grdn:21.078 lr:1.0e-05 updt_s:0.568 data_s:0.002
# INFO 2025-08-28 13:17:43 ts/train.py:232 step:6K smpl:51K ep:66 epch:2.18 loss:0.237 grdn:21.010 lr:1.0e-05 updt_s:0.568 data_s:0.002
# INFO 2025-08-28 13:19:37 ts/train.py:232 step:7K smpl:53K ep:68 epch:2.25 loss:0.229 grdn:20.106 lr:1.0e-05 updt_s:0.567 data_s:0.002
# INFO 2025-08-28 13:21:31 ts/train.py:232 step:7K smpl:54K ep:70 epch:2.32 loss:0.225 grdn:19.679 lr:1.0e-05 updt_s:0.567 data_s:0.002
# INFO 2025-08-28 13:23:25 ts/train.py:232 step:7K smpl:56K ep:72 epch:2.39 loss:0.220 grdn:19.654 lr:1.0e-05 updt_s:0.567 data_s:0.002
# INFO 2025-08-28 13:25:19 ts/train.py:232 step:7K smpl:58K ep:74 epch:2.46 loss:0.209 grdn:18.915 lr:1.0e-05 updt_s:0.566 data_s:0.002
# INFO 2025-08-28 13:27:13 ts/train.py:232 step:7K smpl:59K ep:76 epch:2.53 loss:0.209 grdn:18.939 lr:1.0e-05 updt_s:0.569 data_s:0.002
# INFO 2025-08-28 13:29:07 ts/train.py:232 step:8K smpl:61K ep:78 epch:2.59 loss:0.193 grdn:17.880 lr:1.0e-05 updt_s:0.568 data_s:0.002
# INFO 2025-08-28 13:31:01 ts/train.py:232 step:8K smpl:62K ep:80 epch:2.66 loss:0.198 grdn:17.935 lr:1.0e-05 updt_s:0.568 data_s:0.002
# INFO 2025-08-28 13:32:56 ts/train.py:232 step:8K smpl:64K ep:82 epch:2.73 loss:0.190 grdn:18.164 lr:1.0e-05 updt_s:0.568 data_s:0.002
# INFO 2025-08-28 13:34:50 ts/train.py:232 step:8K smpl:66K ep:84 epch:2.80 loss:0.192 grdn:17.642 lr:1.0e-05 updt_s:0.567 data_s:0.002
# INFO 2025-08-28 13:36:43 ts/train.py:232 step:8K smpl:67K ep:86 epch:2.87 loss:0.189 grdn:17.254 lr:1.0e-05 updt_s:0.567 data_s:0.002
# INFO 2025-08-28 13:38:37 ts/train.py:232 step:9K smpl:69K ep:88 epch:2.93 loss:0.185 grdn:17.294 lr:1.0e-05 updt_s:0.567 data_s:0.001
# INFO 2025-08-28 13:40:34 ts/train.py:232 step:9K smpl:70K ep:90 epch:3.00 loss:0.181 grdn:16.710 lr:1.0e-05 updt_s:0.568 data_s:0.013
# INFO 2025-08-28 13:42:28 ts/train.py:232 step:9K smpl:72K ep:92 epch:3.07 loss:0.173 grdn:16.651 lr:1.0e-05 updt_s:0.568 data_s:0.002
# INFO 2025-08-28 13:44:22 ts/train.py:232 step:9K smpl:74K ep:94 epch:3.14 loss:0.171 grdn:16.249 lr:1.0e-05 updt_s:0.567 data_s:0.001
# INFO 2025-08-28 13:46:16 ts/train.py:232 step:9K smpl:75K ep:96 epch:3.21 loss:0.171 grdn:16.143 lr:1.0e-05 updt_s:0.567 data_s:0.001
# INFO 2025-08-28 13:48:10 ts/train.py:232 step:10K smpl:77K ep:98 epch:3.28 loss:0.169 grdn:15.768 lr:1.0e-05 updt_s:0.567 data_s:0.002
# INFO 2025-08-28 13:50:04 ts/train.py:232 step:10K smpl:78K ep:100 epch:3.34 loss:0.167 grdn:16.145 lr:1.0e-05 updt_s:0.568 data_s:0.002
# INFO 2025-08-28 13:51:59 ts/train.py:232 step:10K smpl:80K ep:102 epch:3.41 loss:0.160 grdn:15.435 lr:1.0e-05 updt_s:0.569 data_s:0.002
# INFO 2025-08-28 13:53:53 ts/train.py:232 step:10K smpl:82K ep:104 epch:3.48 loss:0.156 grdn:15.478 lr:1.0e-05 updt_s:0.568 data_s:0.002
# INFO 2025-08-28 13:55:47 ts/train.py:232 step:10K smpl:83K ep:106 epch:3.55 loss:0.162 grdn:15.042 lr:1.0e-05 updt_s:0.567 data_s:0.002
# INFO 2025-08-28 13:57:41 ts/train.py:232 step:11K smpl:85K ep:109 epch:3.62 loss:0.156 grdn:15.196 lr:1.0e-05 updt_s:0.568 data_s:0.002
# INFO 2025-08-28 13:59:35 ts/train.py:232 step:11K smpl:86K ep:111 epch:3.69 loss:0.157 grdn:14.756 lr:1.0e-05 updt_s:0.567 data_s:0.001
# INFO 2025-08-28 14:01:30 ts/train.py:232 step:11K smpl:88K ep:113 epch:3.75 loss:0.146 grdn:14.226 lr:1.0e-05 updt_s:0.568 data_s:0.002
# INFO 2025-08-28 14:03:24 ts/train.py:232 step:11K smpl:90K ep:115 epch:3.82 loss:0.155 grdn:14.667 lr:1.0e-05 updt_s:0.567 data_s:0.002
# INFO 2025-08-28 14:05:18 ts/train.py:232 step:11K smpl:91K ep:117 epch:3.89 loss:0.148 grdn:14.501 lr:1.0e-05 updt_s:0.568 data_s:0.002
# INFO 2025-08-28 14:07:12 ts/train.py:232 step:12K smpl:93K ep:119 epch:3.96 loss:0.143 grdn:14.295 lr:1.0e-05 updt_s:0.568 data_s:0.002
# INFO 2025-08-28 14:09:08 ts/train.py:232 step:12K smpl:94K ep:121 epch:4.03 loss:0.144 grdn:14.160 lr:1.0e-05 updt_s:0.566 data_s:0.011
# INFO 2025-08-28 14:11:02 ts/train.py:232 step:12K smpl:96K ep:123 epch:4.09 loss:0.139 grdn:14.144 lr:1.0e-05 updt_s:0.568 data_s:0.002
# INFO 2025-08-28 14:12:56 ts/train.py:232 step:12K smpl:98K ep:125 epch:4.16 loss:0.143 grdn:14.068 lr:1.0e-05 updt_s:0.567 data_s:0.001
# INFO 2025-08-28 14:14:50 ts/train.py:232 step:12K smpl:99K ep:127 epch:4.23 loss:0.140 grdn:13.776 lr:1.0e-05 updt_s:0.567 data_s:0.002
# INFO 2025-08-28 14:16:44 ts/train.py:232 step:13K smpl:101K ep:129 epch:4.30 loss:0.138 grdn:13.560 lr:1.0e-05 updt_s:0.569 data_s:0.002
# INFO 2025-08-28 14:18:38 ts/train.py:232 step:13K smpl:102K ep:131 epch:4.37 loss:0.138 grdn:13.538 lr:1.0e-05 updt_s:0.567 data_s:0.002
# INFO 2025-08-28 14:20:32 ts/train.py:232 step:13K smpl:104K ep:133 epch:4.44 loss:0.132 grdn:12.890 lr:1.0e-05 updt_s:0.567 data_s:0.002
# INFO 2025-08-28 14:22:26 ts/train.py:232 step:13K smpl:106K ep:135 epch:4.50 loss:0.130 grdn:13.221 lr:1.0e-05 updt_s:0.567 data_s:0.001
# INFO 2025-08-28 14:24:20 ts/train.py:232 step:13K smpl:107K ep:137 epch:4.57 loss:0.134 grdn:13.020 lr:1.0e-05 updt_s:0.567 data_s:0.001
# INFO 2025-08-28 14:26:14 ts/train.py:232 step:14K smpl:109K ep:139 epch:4.64 loss:0.134 grdn:13.030 lr:1.0e-05 updt_s:0.567 data_s:0.002
# INFO 2025-08-28 14:28:08 ts/train.py:232 step:14K smpl:110K ep:141 epch:4.71 loss:0.134 grdn:12.879 lr:1.0e-05 updt_s:0.567 data_s:0.002
# INFO 2025-08-28 14:30:02 ts/train.py:232 step:14K smpl:112K ep:143 epch:4.78 loss:0.133 grdn:12.841 lr:1.0e-05 updt_s:0.567 data_s:0.002
# INFO 2025-08-28 14:31:56 ts/train.py:232 step:14K smpl:114K ep:145 epch:4.85 loss:0.131 grdn:12.602 lr:1.0e-05 updt_s:0.568 data_s:0.002
# INFO 2025-08-28 14:33:50 ts/train.py:232 step:14K smpl:115K ep:147 epch:4.91 loss:0.130 grdn:12.714 lr:1.0e-05 updt_s:0.567 data_s:0.002
# INFO 2025-08-28 14:35:45 ts/train.py:232 step:15K smpl:117K ep:149 epch:4.98 loss:0.126 grdn:12.405 lr:1.0e-05 updt_s:0.568 data_s:0.002
# INFO 2025-08-28 14:37:40 ts/train.py:232 step:15K smpl:118K ep:152 epch:5.05 loss:0.127 grdn:12.141 lr:1.0e-05 updt_s:0.566 data_s:0.008
# INFO 2025-08-28 14:39:34 ts/train.py:232 step:15K smpl:120K ep:154 epch:5.12 loss:0.122 grdn:11.818 lr:1.0e-05 updt_s:0.568 data_s:0.002
# INFO 2025-08-28 14:41:28 ts/train.py:232 step:15K smpl:122K ep:156 epch:5.19 loss:0.126 grdn:11.777 lr:1.0e-05 updt_s:0.567 data_s:0.001

# %% [markdown]
# ## Login into Hugging Face Hub
# Now after training is done login into the Hugging Face hub and upload the last checkpoint

# %%
# !huggingface-cli login

# %%
# !huggingface-cli upload ${HF_USER}/il_sim_test0 \
  /content/lerobot/outputs/train/il_sim_test0/checkpoints/last/pretrained_model
